# %% [markdown]
# # Train a convolutional neural network

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %% [markdown]
# ## Import libraries

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 13 19:35:11 2019

@author: hippolyte
"""

import os
import h5py
import imgaug.augmenters as iaa
import numpy as np
import tensorflow as tf
import imgaug as aug
import datetime
import pickle

from keras.applications import vgg16, vgg19, xception
from keras.models import Model, Sequential, load_model, save_model
from keras.layers import Input, Conv2D, SeparableConv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.engine import InputLayer

from matplotlib import pyplot as plt
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Global variables

# %%
################################################################################
### MODIFIABLE VARIABLES
################################################################################
ROOT_PATH = 'drive/My Drive/master1/medical_image_recognition/'
DATASET_NAME = 'chest_xray'
IMAGE_EXTENSIONS = ['*.jpg', '*.jpeg']

################################################################################
### DON'T CHANGE THESE VARIABLES
################################################################################
DATASET_PATH = ROOT_PATH + 'datasets/' + DATASET_NAME + '/'
ARRAY_PATH   = ROOT_PATH + 'arrays/'   + DATASET_NAME + '/'
MODEL_PATH   = ROOT_PATH + 'models/'   + DATASET_NAME + '/'
# create the directory to save arrays if it doesn't exist
#! mkdir -pv ARRAY_PATH, MODEL_PATH

# get directories and labels
DIRECTORIES = sorted([d for d in os.listdir(DATASET_PATH)])
LABELS = sorted(os.listdir(DATASET_PATH + DIRECTORIES[0]))
# helpers for labels
NUM_LABELS = len(LABELS)
LABEL_MAPPING = {label: code for code, label in enumerate(LABELS)}
# helper for paths
PATHS = {directory: DATASET_PATH + directory + '/' for directory in DIRECTORIES}

# %%
print(DIRECTORIES)
print(LABELS)
print(LABEL_MAPPING)
# Out:
# ['test', 'train', 'val']
# ['NORMAL', 'PNEUMONIA']
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %% [markdown]
# ## Fix seeds to have reproducible results
#
# https://keras.io/getting-started/faq/#how-can-i-obtain-reproducible-results-using-keras-during-development

# %%
# the next instructions are used to make results reproducible
SEED = 1234
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(SEED)
tf.set_random_seed(SEED)
aug.seed(SEED)

# %% [markdown]
# ## Data function

# %%
def label_code_to_str(label_code: int) -> str:
    """
    TODO
    """
    for label, code in LABEL_MAPPING.items():
        if label_code == code:
            return label

    raise ValueError('Couldn\'t find the code {} in labels'.format(label_code))

def get_data_dir(directory: str,
                 array_dir: str,
                 height: int=224,
                 width: int=224,
                 channels: int=3):
    """
    TODO
    """
    shape_str = '({},{},{})pr'.format(height, width, channels)
    filename = array_dir + directory + shape_str + '.h5'
    print('Getting {} images from {}'.format(shape_str, filename))
    
    # some helper variables
    start = datetime.datetime.now()
    
    with h5py.File(filename, 'r') as file:
        # assuming the file contains same amount of image and labels
        num_images = np.ceil(len(file.keys()) / 2).astype(int)

        # define arrays holding data and labels
        data = np.zeros((num_images, height, width, channels), dtype=np.float32)
        labels = np.zeros((num_images, NUM_LABELS), dtype=np.float32)

        # iterate over all images
        # format is x0 y0 for the first image and so on
        for image_index in range(num_images):
            image = file['x' + str(image_index)]
            label = file['y' + str(image_index)]

            data[image_index] = image
            labels[image_index] = label

    # shapes
    print('Data shape : {}\nLabels shape : {}'.format(data.shape, labels.shape))
    
    end = datetime.datetime.now()
    print('Found {} images in {} seconds.'.format(data.shape[0],
                                                 (end-start).seconds))
    
    return data, labels

# %% [markdown]
# ## Convolutional Neural Network functions

# %% [markdown]
# ### Create the network

# %%
def create_vgg19(include_top=True,
                 input_shape=(224, 224, 3),
                 frozen_layers=None):
    """
    TODO
    """
    # create the VGG model
    vgg19_model = vgg19.VGG19(include_top=include_top,
                              weights='imagenet',
                              input_shape=input_shape)
    # model name
    frozen_layers_str = '_'.join(frozen_layers) if frozen_layers else ''
    
    if include_top is True:
        # create a sequential model with corresponding name
        model_name = 'vgg19_' + frozen_layers_str
        model = Sequential(name=model_name)

        # add input layer at bottom
        model.add(InputLayer(input_shape=input_shape))

        # transform the vgg model into sequential
        # taking care to not add the last layer containing the dense layer
        for layer in vgg19_model.layers[:-1]:
            model.add(layer)

        # add last layer
        model.add(Dense(NUM_LABELS, activation='softmax', name='predictions'))
    
    else:
        # create a sequential model with corresponding name
        model_name = 'vgg19_custom_' + frozen_layers_str
        model = Sequential(name=model_name)
        
        # add input layer at bottom
        model.add(InputLayer(input_shape=input_shape))
        
        # add the vgg model to model
        for layer in vgg19_model.layers:
            model.add(layer)
        
        # add classification block
        model.add(Flatten(name='flatten'))
        model.add(Dense(1024, activation='relu', name='fc1')) #1024
        model.add(Dropout(0.7, name='dropout1'))              #notpresent
        model.add(Dense(512, activation='relu', name='fc2'))  #512
        model.add(Dropout(0.5, name='dropout2'))              #notpresent
        model.add(Dense(NUM_LABELS, activation='softmax', name='predictions'))
    
    ###################
    ### FREEZE PART ###
    ###################
    
    if frozen_layers is None:
        print('Everything is trainable.')
    
    else:
        # freeze the first 5 blocks
        if 'blocks' in frozen_layers:
            for i, layer in enumerate(model.layers):
                if layer.name not in ['fc1', 'fc2']:
                    layer.trainable = False

            print('Froze all blocks before classification one.')

        # freeze fc1
        if 'fc1' in frozen_layers:
            model.get_layer('fc1').trainable = False
            print('Froze fc1.')

        # freeze fc2
        if 'fc2' in frozen_layers:
            model.get_layer('fc2').trainable = False
            print('Froze fc2.')
    
    #####################
    ### COMPILE MODEL ###
    #####################
    
    loss_type = 'binary' if NUM_LABELS == 2 else 'categorical'
    loss_type += '_crossentropy'
    optimizer = Adam(lr=1e-6, decay=1e-5)
    
    model.compile(loss=loss_type,
                  metrics=['accuracy'],
                  optimizer=optimizer)
        
    return model

# %% [markdown]
# ### Training function

# %%
def train_model(model,
                train_data,
                train_labels,
                val_data,
                val_labels,
                epoch=50,
                batch_size=32,
                metric='val_loss',
                save_best_only=True,
                save_model_path=None,
                save_weights_only=True,
                stop_after=10,
                save_history=True,
                save_history_path=None,
                class_weight_mapping=None):
    """
    TODO
    """
    # callbacks
    early_stopping = EarlyStopping(patience=stop_after,
                                   monitor=metric,
                                   restore_best_weights=True)
    
    checkpoint = ModelCheckpoint(save_model_path,
                                 monitor=metric,
                                 verbose=1,
                                 save_best_only=save_best_only,
                                 save_weights_only=save_weights_only)

    # here we are, we'll train the model
    history = model.fit(x=train_data,
                        y=train_labels,
                        batch_size=batch_size,
                        epochs=epoch,
                        verbose=1,
                        callbacks=[early_stopping, checkpoint],
                        validation_split=0.0,
                        validation_data=(val_data, val_labels),
                        shuffle=True,
                        class_weight=class_weight_mapping)

    # save history
    if save_history:
        with open(save_history_path, 'wb') as file:
            pickle.dump(history.history, file)
        print('\n\nSaved history into {}'.format(save_history_path))
    
    return model, history

# %% [markdown]
# ### Plot results of the network

# %%
def plot_model_performance(model,
                           test_data,
                           test_labels,
                           batch_size=16):
    """
    TODO
    """
    print('Performances for {} model.'.format(model.name))
    print('\n\n')
    test_loss, test_score = model.evaluate(test_data,
                                           test_labels,
                                           batch_size=16)
    print('Loss : {}'.format(test_loss))
    print('Score : {}'.format(test_score))
    print('\n\n')

    # predictions and groud truth
    preds = model.predict(test_data, batch_size=16)
    preds = np.argmax(preds, axis=-1)
    ground_truth = np.argmax(test_labels, axis=-1)
    
    # confusion matrix
    cm  = confusion_matrix(ground_truth, preds)
    
    # metrics
    recall = np.diag(cm) / np.sum(cm, axis=1)
    precision = np.diag(cm) / np.sum(cm, axis=0)
    accuracy = np.diag(cm) / np.sum(cm)

    print('Recall : {}'.format(recall))
    print('Precision : {}'.format(precision))
    print('Accuracy : {}'.format(accuracy))
    print('\n\n')

    # plot confusion matrix
    plt.figure()
    plot_confusion_matrix(cm,
                          figsize=(12, 8),
                          hide_ticks=True,
                          cmap=plt.cm.Blues)
    plt.xticks(range(NUM_LABELS), LABELS) #, fontsize=16)
    plt.yticks(range(NUM_LABELS), LABELS) #, fontsize=16)
    plt.show()
    
def plot_model_history(history_path):
    """
    TODO
    """
    print('Loading history from {}'.format(history_path))
    history = pickle.load(open(history_path, 'rb'))

    fig, axes = plt.subplots(1, 2, figsize=(12, 4)) #, constrained_layout=True)

    # accuracy
    axes[0].plot(history['acc'])
    axes[0].plot(history['val_acc'])
    axes[0].set_title('Model Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].legend(['train', 'val'])

    # loss
    axes[1].plot(history['loss'])
    axes[1].plot(history['val_loss'])
    axes[1].set_title('Model Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epochs')
    axes[1].legend(['train', 'val'])
    plt.show()

# %% [markdown]
# ## Let's do it !

# %% [markdown]
# ### Data part

# %%
HEIGHT, WIDTH, CHANNELS = 224, 224, 3

data, labels = dict(), dict()

for directory in DIRECTORIES:
    # get data and labels
    data[directory], labels[directory] = get_data_dir(directory,
                                                      array_dir=ARRAY_PATH,
                                                      height=HEIGHT,
                                                      width=WIDTH,
                                                      channels=CHANNELS)
    
    # get a random index
    ind = np.random.randint(data[directory].shape[0])

    # plot the image with label
    plt.imshow(data[directory][ind])
    img_label = np.argmax(labels[directory][ind])
    img_label_str = label_code_to_str(img_label)
    #plt.title(img_label_str, img_label)
    print('{}({})'.format(img_label, img_label_str))
    plt.show()
# Out:
# Getting (224,224,3)pr images from drive/My Drive/master1/medical_image_recognition/arrays/chest_xray/test(224,224,3)pr.h5
# Data shape : (624, 224, 224, 3)
# Labels shape : (624, 2)
# Found 624 images in 4 seconds.
# 1(PNEUMONIA)
# Getting (224,224,3)pr images from drive/My Drive/master1/medical_image_recognition/arrays/chest_xray/train(224,224,3)pr.h5
# Data shape : (5221, 224, 224, 3)
# Labels shape : (5221, 2)
# Found 5221 images in 32 seconds.
# 1(PNEUMONIA)
# Getting (224,224,3)pr images from drive/My Drive/master1/medical_image_recognition/arrays/chest_xray/val(224,224,3)pr.h5
# Data shape : (16, 224, 224, 3)
# Labels shape : (16, 2)
# Found 16 images in 0 seconds.
# 0(NORMAL)

# %% [markdown]
# ### CNN creation

# %%
model = create_vgg19(include_top=True,
                     input_shape=(HEIGHT, WIDTH, CHANNELS),
                     frozen_layers=['blocks', 'fc1'])

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Froze all blocks before classification one.
# Froze fc1.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 8194
# =================================================================
# Total params: 139,578,434
# Trainable params: 16,781,312
# Non-trainable params: 122,797,122
# _________________________________________________________________

# %% [markdown]
# ### CNN training
# #### USE IT WITH CAUTION, IT CAN TAKE TIME

# %%
import pandas as pd
import math
df = pd.DataFrame(labels['train'])
d = dict(df[0].value_counts())
print(d)
# Out:
# {0.0: 3875, 1.0: 1346}

# %%
print(d[1] / d[0])
# Out:
# 0.3473548387096774

# %%
CLASS_WEIGHT_MAPPING = {0: 3., 1: 1.}

# %% [markdown]
# ### Xception

# %%
def create_xception(include_top=True,
                    input_shape=(299, 299, 3),
                    frozen_layers=None):
    """
    TODO
    """
    xception_model = xception.Xception(include_top=include_top,
                                       weights='imagenet',
                                       input_shape=input_shape)

    model = Sequential()
    model.add(xception_model)
    
    # model name
    frozen_layers_str = '_'.join(frozen_layers) if frozen_layers else ''
    
    if include_top is True:
        # create a sequential model with corresponding name
        model_name = 'xception_' + frozen_layers_str
        model = Sequential(name=model_name)

        # add input layer at bottom
        model.add(InputLayer(input_shape=input_shape))

        # transform the vgg model into sequential
        # taking care to not add the last layer containing the dense layer
        for layer in xception_model.layers[:-1]:
            model.add(layer)

        # add last layer
        model.add(Dense(NUM_LABELS, activation='softmax', name='predictions'))
    
    else:
        # create a sequential model with corresponding name
        model_name = 'xception_custom_' + frozen_layers_str
        model = Sequential(name=model_name)
        
        # add input layer at bottom
        model.add(InputLayer(input_shape=input_shape))
        
        # add the vgg model to model
        for layer in xception_model.layers:
            model.add(layer)
        
        # add classification block
        model.add(Flatten(name='flatten'))
        model.add(Dense(1024, activation='relu', name='fc1')) #1024
        model.add(Dropout(0.7, name='dropout1'))              #notpresent
        model.add(Dense(512, activation='relu', name='fc2'))  #512
        model.add(Dropout(0.5, name='dropout2'))              #notpresent
        model.add(Dense(NUM_LABELS, activation='softmax', name='predictions'))
    
    ###################
    ### FREEZE PART ###
    ###################
    
    if frozen_layers is None:
        print('Everything is trainable.')
    
    else:
        # freeze the first 5 blocks
        if 'blocks' in frozen_layers:
            for i, layer in enumerate(model.layers):
                if layer.name not in ['fc1', 'fc2']:
                    layer.trainable = False

            print('Froze all blocks before classification one.')

        # freeze fc1
        if 'fc1' in frozen_layers:
            model.get_layer('fc1').trainable = False
            print('Froze fc1.')

        # freeze fc2
        if 'fc2' in frozen_layers:
            model.get_layer('fc2').trainable = False
            print('Froze fc2.')
    
    #####################
    ### COMPILE MODEL ###
    #####################
    
    loss_type = 'binary' if NUM_LABELS == 2 else 'categorical'
    loss_type += '_crossentropy'
    optimizer = Adam(lr=1e-6, decay=1e-5)
    
    model.compile(loss=loss_type,
                  metrics=['accuracy'],
                  optimizer=optimizer)

    return model

# %%
SAVE_MODEL_PATH = MODEL_PATH + model.name + '_model.hdf5'
SAVE_HISTORY_PATH = MODEL_PATH + model.name + '_history'

model, history = train_model(model,
                             train_data=data['train'],
                             train_labels=labels['train'],
                             val_data=data['test'],
                             val_labels=labels['test'],
                             epoch=200,
                             batch_size=32,
                             metric='val_acc',
                             save_best_only=True,
                             save_model_path=SAVE_MODEL_PATH,
                             save_weights_only=False,
                             stop_after=25,
                             save_history=True,
                             save_history_path=SAVE_HISTORY_PATH,
                             class_weight_mapping=CLASS_WEIGHT_MAPPING)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 5221 samples, validate on 624 samples
# Epoch 1/200
# 5221/5221 [==============================] - 43s 8ms/step - loss: 0.8225 - acc: 0.7878 - val_loss: 0.5236 - val_acc: 0.7869
#
# Epoch 00001: val_acc improved from -inf to 0.78686, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 2/200
# 5221/5221 [==============================] - 37s 7ms/step - loss: 0.6788 - acc: 0.8604 - val_loss: 0.4975 - val_acc: 0.8237
#
# Epoch 00002: val_acc improved from 0.78686 to 0.82372, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 3/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.6128 - acc: 0.8655 - val_loss: 0.4664 - val_acc: 0.8253
#
# Epoch 00003: val_acc improved from 0.82372 to 0.82532, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 4/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.5669 - acc: 0.8717 - val_loss: 0.4506 - val_acc: 0.8317
#
# Epoch 00004: val_acc improved from 0.82532 to 0.83173, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 5/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.5309 - acc: 0.8791 - val_loss: 0.4327 - val_acc: 0.8157
#
# Epoch 00005: val_acc did not improve from 0.83173
# Epoch 6/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.5032 - acc: 0.8803 - val_loss: 0.4191 - val_acc: 0.8333
#
# Epoch 00006: val_acc improved from 0.83173 to 0.83333, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 7/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.4806 - acc: 0.8839 - val_loss: 0.4094 - val_acc: 0.8221
#
# Epoch 00007: val_acc did not improve from 0.83333
# Epoch 8/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.4626 - acc: 0.8891 - val_loss: 0.3986 - val_acc: 0.8397
#
# Epoch 00008: val_acc improved from 0.83333 to 0.83974, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 9/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.4439 - acc: 0.8927 - val_loss: 0.3909 - val_acc: 0.8413
#
# Epoch 00009: val_acc improved from 0.83974 to 0.84135, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 10/200
# 5221/5221 [==============================] - 37s 7ms/step - loss: 0.4292 - acc: 0.8931 - val_loss: 0.3822 - val_acc: 0.8397
#
# Epoch 00010: val_acc did not improve from 0.84135
# Epoch 11/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.4177 - acc: 0.8958 - val_loss: 0.3753 - val_acc: 0.8494
#
# Epoch 00011: val_acc improved from 0.84135 to 0.84936, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 12/200
# 5221/5221 [==============================] - 37s 7ms/step - loss: 0.4057 - acc: 0.8975 - val_loss: 0.3708 - val_acc: 0.8397
#
# Epoch 00012: val_acc did not improve from 0.84936
# Epoch 13/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3949 - acc: 0.8998 - val_loss: 0.3695 - val_acc: 0.8349
#
# Epoch 00013: val_acc did not improve from 0.84936
# Epoch 14/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3928 - acc: 0.8983 - val_loss: 0.3614 - val_acc: 0.8446
#
# Epoch 00014: val_acc did not improve from 0.84936
# Epoch 15/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3772 - acc: 0.9012 - val_loss: 0.3607 - val_acc: 0.8365
#
# Epoch 00015: val_acc did not improve from 0.84936
# Epoch 16/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3704 - acc: 0.9035 - val_loss: 0.3730 - val_acc: 0.8317
#
# Epoch 00016: val_acc did not improve from 0.84936
# Epoch 17/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3651 - acc: 0.9086 - val_loss: 0.3528 - val_acc: 0.8397
#
# Epoch 00017: val_acc did not improve from 0.84936
# Epoch 18/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3592 - acc: 0.9071 - val_loss: 0.3504 - val_acc: 0.8429
#
# Epoch 00018: val_acc did not improve from 0.84936
# Epoch 19/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3517 - acc: 0.9094 - val_loss: 0.3469 - val_acc: 0.8446
#
# Epoch 00019: val_acc did not improve from 0.84936
# Epoch 20/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3492 - acc: 0.9090 - val_loss: 0.3380 - val_acc: 0.8526
#
# Epoch 00020: val_acc improved from 0.84936 to 0.85256, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 21/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3404 - acc: 0.9107 - val_loss: 0.3331 - val_acc: 0.8622
#
# Epoch 00021: val_acc improved from 0.85256 to 0.86218, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 22/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3369 - acc: 0.9117 - val_loss: 0.3309 - val_acc: 0.8654
#
# Epoch 00022: val_acc improved from 0.86218 to 0.86538, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 23/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3344 - acc: 0.9121 - val_loss: 0.3314 - val_acc: 0.8526
#
# Epoch 00023: val_acc did not improve from 0.86538
# Epoch 24/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3276 - acc: 0.9130 - val_loss: 0.3574 - val_acc: 0.8446
#
# Epoch 00024: val_acc did not improve from 0.86538
# Epoch 25/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3214 - acc: 0.9180 - val_loss: 0.3296 - val_acc: 0.8574
#
# Epoch 00025: val_acc did not improve from 0.86538
# Epoch 26/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3193 - acc: 0.9169 - val_loss: 0.3238 - val_acc: 0.8590
#
# Epoch 00026: val_acc did not improve from 0.86538
# Epoch 27/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3202 - acc: 0.9142 - val_loss: 0.3385 - val_acc: 0.8574
#
# Epoch 00027: val_acc did not improve from 0.86538
# Epoch 28/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3103 - acc: 0.9205 - val_loss: 0.3186 - val_acc: 0.8606
#
# Epoch 00028: val_acc did not improve from 0.86538
# Epoch 29/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3063 - acc: 0.9201 - val_loss: 0.3193 - val_acc: 0.8590
#
# Epoch 00029: val_acc did not improve from 0.86538
# Epoch 30/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3055 - acc: 0.9213 - val_loss: 0.3167 - val_acc: 0.8622
#
# Epoch 00030: val_acc did not improve from 0.86538
# Epoch 31/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.3011 - acc: 0.9224 - val_loss: 0.3133 - val_acc: 0.8622
#
# Epoch 00031: val_acc did not improve from 0.86538
# Epoch 32/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2992 - acc: 0.9236 - val_loss: 0.3125 - val_acc: 0.8606
#
# Epoch 00032: val_acc did not improve from 0.86538
# Epoch 33/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2962 - acc: 0.9228 - val_loss: 0.3270 - val_acc: 0.8622
#
# Epoch 00033: val_acc did not improve from 0.86538
# Epoch 34/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2935 - acc: 0.9236 - val_loss: 0.3188 - val_acc: 0.8670
#
# Epoch 00034: val_acc improved from 0.86538 to 0.86699, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 35/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2904 - acc: 0.9257 - val_loss: 0.3170 - val_acc: 0.8670
#
# Epoch 00035: val_acc did not improve from 0.86699
# Epoch 36/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2895 - acc: 0.9257 - val_loss: 0.3274 - val_acc: 0.8638
#
# Epoch 00036: val_acc did not improve from 0.86699
# Epoch 37/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2856 - acc: 0.9266 - val_loss: 0.3128 - val_acc: 0.8670
#
# Epoch 00037: val_acc did not improve from 0.86699
# Epoch 38/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2819 - acc: 0.9266 - val_loss: 0.3400 - val_acc: 0.8526
#
# Epoch 00038: val_acc did not improve from 0.86699
# Epoch 39/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2779 - acc: 0.9274 - val_loss: 0.3584 - val_acc: 0.8478
#
# Epoch 00039: val_acc did not improve from 0.86699
# Epoch 40/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2772 - acc: 0.9282 - val_loss: 0.3507 - val_acc: 0.8526
#
# Epoch 00040: val_acc did not improve from 0.86699
# Epoch 41/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2762 - acc: 0.9274 - val_loss: 0.3357 - val_acc: 0.8558
#
# Epoch 00041: val_acc did not improve from 0.86699
# Epoch 42/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2727 - acc: 0.9278 - val_loss: 0.3022 - val_acc: 0.8670
#
# Epoch 00042: val_acc did not improve from 0.86699
# Epoch 43/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2708 - acc: 0.9309 - val_loss: 0.3084 - val_acc: 0.8718
#
# Epoch 00043: val_acc improved from 0.86699 to 0.87179, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 44/200
# 5221/5221 [==============================] - 37s 7ms/step - loss: 0.2680 - acc: 0.9312 - val_loss: 0.2971 - val_acc: 0.8686
#
# Epoch 00044: val_acc did not improve from 0.87179
# Epoch 45/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2674 - acc: 0.9286 - val_loss: 0.3379 - val_acc: 0.8558
#
# Epoch 00045: val_acc did not improve from 0.87179
# Epoch 46/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2652 - acc: 0.9287 - val_loss: 0.2999 - val_acc: 0.8670
#
# Epoch 00046: val_acc did not improve from 0.87179
# Epoch 47/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2634 - acc: 0.9339 - val_loss: 0.2991 - val_acc: 0.8670
#
# Epoch 00047: val_acc did not improve from 0.87179
# Epoch 48/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2635 - acc: 0.9303 - val_loss: 0.3083 - val_acc: 0.8782
#
# Epoch 00048: val_acc improved from 0.87179 to 0.87821, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 49/200
# 5221/5221 [==============================] - 37s 7ms/step - loss: 0.2598 - acc: 0.9320 - val_loss: 0.3152 - val_acc: 0.8734
#
# Epoch 00049: val_acc did not improve from 0.87821
# Epoch 50/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2579 - acc: 0.9307 - val_loss: 0.3057 - val_acc: 0.8766
#
# Epoch 00050: val_acc did not improve from 0.87821
# Epoch 51/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2559 - acc: 0.9339 - val_loss: 0.3087 - val_acc: 0.8782
#
# Epoch 00051: val_acc did not improve from 0.87821
# Epoch 52/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2555 - acc: 0.9364 - val_loss: 0.2903 - val_acc: 0.8782
#
# Epoch 00052: val_acc did not improve from 0.87821
# Epoch 53/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2558 - acc: 0.9328 - val_loss: 0.3026 - val_acc: 0.8782
#
# Epoch 00053: val_acc did not improve from 0.87821
# Epoch 54/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2515 - acc: 0.9358 - val_loss: 0.3122 - val_acc: 0.8782
#
# Epoch 00054: val_acc did not improve from 0.87821
# Epoch 55/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2485 - acc: 0.9347 - val_loss: 0.3119 - val_acc: 0.8782
#
# Epoch 00055: val_acc did not improve from 0.87821
# Epoch 56/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2499 - acc: 0.9328 - val_loss: 0.3672 - val_acc: 0.8494
#
# Epoch 00056: val_acc did not improve from 0.87821
# Epoch 57/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2499 - acc: 0.9355 - val_loss: 0.3606 - val_acc: 0.8494
#
# Epoch 00057: val_acc did not improve from 0.87821
# Epoch 58/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2506 - acc: 0.9353 - val_loss: 0.3020 - val_acc: 0.8782
#
# Epoch 00058: val_acc did not improve from 0.87821
# Epoch 59/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2441 - acc: 0.9355 - val_loss: 0.3068 - val_acc: 0.8766
#
# Epoch 00059: val_acc did not improve from 0.87821
# Epoch 60/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2420 - acc: 0.9387 - val_loss: 0.3015 - val_acc: 0.8798
#
# Epoch 00060: val_acc improved from 0.87821 to 0.87981, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 61/200
# 5221/5221 [==============================] - 37s 7ms/step - loss: 0.2412 - acc: 0.9358 - val_loss: 0.3282 - val_acc: 0.8686
#
# Epoch 00061: val_acc did not improve from 0.87981
# Epoch 62/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2403 - acc: 0.9383 - val_loss: 0.3154 - val_acc: 0.8766
#
# Epoch 00062: val_acc did not improve from 0.87981
# Epoch 63/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2392 - acc: 0.9381 - val_loss: 0.3191 - val_acc: 0.8782
#
# Epoch 00063: val_acc did not improve from 0.87981
# Epoch 64/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2408 - acc: 0.9364 - val_loss: 0.2945 - val_acc: 0.8798
#
# Epoch 00064: val_acc did not improve from 0.87981
# Epoch 65/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2383 - acc: 0.9368 - val_loss: 0.3238 - val_acc: 0.8734
#
# Epoch 00065: val_acc did not improve from 0.87981
# Epoch 66/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2350 - acc: 0.9402 - val_loss: 0.3106 - val_acc: 0.8782
#
# Epoch 00066: val_acc did not improve from 0.87981
# Epoch 67/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2342 - acc: 0.9379 - val_loss: 0.2957 - val_acc: 0.8846
#
# Epoch 00067: val_acc improved from 0.87981 to 0.88462, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 68/200
# 5221/5221 [==============================] - 37s 7ms/step - loss: 0.2328 - acc: 0.9408 - val_loss: 0.2973 - val_acc: 0.8862
#
# Epoch 00068: val_acc improved from 0.88462 to 0.88622, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 69/200
# 5221/5221 [==============================] - 37s 7ms/step - loss: 0.2324 - acc: 0.9383 - val_loss: 0.3200 - val_acc: 0.8766
#
# Epoch 00069: val_acc did not improve from 0.88622
# Epoch 70/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2311 - acc: 0.9425 - val_loss: 0.3486 - val_acc: 0.8590
#
# Epoch 00070: val_acc did not improve from 0.88622
# Epoch 71/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2319 - acc: 0.9412 - val_loss: 0.2921 - val_acc: 0.8862
#
# Epoch 00071: val_acc did not improve from 0.88622
# Epoch 72/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2287 - acc: 0.9412 - val_loss: 0.2935 - val_acc: 0.8862
#
# Epoch 00072: val_acc did not improve from 0.88622
# Epoch 73/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2279 - acc: 0.9400 - val_loss: 0.3243 - val_acc: 0.8734
#
# Epoch 00073: val_acc did not improve from 0.88622
# Epoch 74/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2267 - acc: 0.9416 - val_loss: 0.2986 - val_acc: 0.8846
#
# Epoch 00074: val_acc did not improve from 0.88622
# Epoch 75/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2249 - acc: 0.9429 - val_loss: 0.3065 - val_acc: 0.8814
#
# Epoch 00075: val_acc did not improve from 0.88622
# Epoch 76/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2242 - acc: 0.9437 - val_loss: 0.3099 - val_acc: 0.8814
#
# Epoch 00076: val_acc did not improve from 0.88622
# Epoch 77/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2228 - acc: 0.9429 - val_loss: 0.3437 - val_acc: 0.8590
#
# Epoch 00077: val_acc did not improve from 0.88622
# Epoch 78/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2230 - acc: 0.9422 - val_loss: 0.2929 - val_acc: 0.8878
#
# Epoch 00078: val_acc improved from 0.88622 to 0.88782, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 79/200
# 5221/5221 [==============================] - 37s 7ms/step - loss: 0.2234 - acc: 0.9433 - val_loss: 0.2850 - val_acc: 0.8814
#
# Epoch 00079: val_acc did not improve from 0.88782
# Epoch 80/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2247 - acc: 0.9410 - val_loss: 0.3173 - val_acc: 0.8750
#
# Epoch 00080: val_acc did not improve from 0.88782
# Epoch 81/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2228 - acc: 0.9416 - val_loss: 0.3256 - val_acc: 0.8718
#
# Epoch 00081: val_acc did not improve from 0.88782
# Epoch 82/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2196 - acc: 0.9450 - val_loss: 0.3341 - val_acc: 0.8638
#
# Epoch 00082: val_acc did not improve from 0.88782
# Epoch 83/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2191 - acc: 0.9441 - val_loss: 0.3058 - val_acc: 0.8846
#
# Epoch 00083: val_acc did not improve from 0.88782
# Epoch 84/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2178 - acc: 0.9439 - val_loss: 0.3154 - val_acc: 0.8798
#
# Epoch 00084: val_acc did not improve from 0.88782
# Epoch 85/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2167 - acc: 0.9460 - val_loss: 0.3217 - val_acc: 0.8750
#
# Epoch 00085: val_acc did not improve from 0.88782
# Epoch 86/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2163 - acc: 0.9446 - val_loss: 0.2927 - val_acc: 0.8878
#
# Epoch 00086: val_acc did not improve from 0.88782
# Epoch 87/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2144 - acc: 0.9448 - val_loss: 0.3121 - val_acc: 0.8814
#
# Epoch 00087: val_acc did not improve from 0.88782
# Epoch 88/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2139 - acc: 0.9452 - val_loss: 0.3459 - val_acc: 0.8622
#
# Epoch 00088: val_acc did not improve from 0.88782
# Epoch 89/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2152 - acc: 0.9460 - val_loss: 0.3449 - val_acc: 0.8622
#
# Epoch 00089: val_acc did not improve from 0.88782
# Epoch 90/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2139 - acc: 0.9466 - val_loss: 0.3096 - val_acc: 0.8830
#
# Epoch 00090: val_acc did not improve from 0.88782
# Epoch 91/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2105 - acc: 0.9487 - val_loss: 0.3431 - val_acc: 0.8622
#
# Epoch 00091: val_acc did not improve from 0.88782
# Epoch 92/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2124 - acc: 0.9466 - val_loss: 0.3480 - val_acc: 0.8638
#
# Epoch 00092: val_acc did not improve from 0.88782
# Epoch 93/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2119 - acc: 0.9458 - val_loss: 0.3288 - val_acc: 0.8670
#
# Epoch 00093: val_acc did not improve from 0.88782
# Epoch 94/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2088 - acc: 0.9469 - val_loss: 0.3390 - val_acc: 0.8638
#
# Epoch 00094: val_acc did not improve from 0.88782
# Epoch 95/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2109 - acc: 0.9448 - val_loss: 0.3402 - val_acc: 0.8638
#
# Epoch 00095: val_acc did not improve from 0.88782
# Epoch 96/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2076 - acc: 0.9489 - val_loss: 0.3033 - val_acc: 0.8862
#
# Epoch 00096: val_acc did not improve from 0.88782
# Epoch 97/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2076 - acc: 0.9466 - val_loss: 0.3189 - val_acc: 0.8750
#
# Epoch 00097: val_acc did not improve from 0.88782
# Epoch 98/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2070 - acc: 0.9489 - val_loss: 0.2869 - val_acc: 0.8894
#
# Epoch 00098: val_acc improved from 0.88782 to 0.88942, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 99/200
# 5221/5221 [==============================] - 37s 7ms/step - loss: 0.2074 - acc: 0.9483 - val_loss: 0.2893 - val_acc: 0.8878
#
# Epoch 00099: val_acc did not improve from 0.88942
# Epoch 100/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2081 - acc: 0.9504 - val_loss: 0.2749 - val_acc: 0.8878
#
# Epoch 00100: val_acc did not improve from 0.88942
# Epoch 101/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2084 - acc: 0.9441 - val_loss: 0.3248 - val_acc: 0.8702
#
# Epoch 00101: val_acc did not improve from 0.88942
# Epoch 102/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2025 - acc: 0.9504 - val_loss: 0.2824 - val_acc: 0.8942
#
# Epoch 00102: val_acc improved from 0.88942 to 0.89423, saving model to drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_model.hdf5
# Epoch 103/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2045 - acc: 0.9473 - val_loss: 0.3580 - val_acc: 0.8606
#
# Epoch 00103: val_acc did not improve from 0.89423
# Epoch 104/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2034 - acc: 0.9510 - val_loss: 0.3333 - val_acc: 0.8670
#
# Epoch 00104: val_acc did not improve from 0.89423
# Epoch 105/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2053 - acc: 0.9491 - val_loss: 0.2945 - val_acc: 0.8878
#
# Epoch 00105: val_acc did not improve from 0.89423
# Epoch 106/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2011 - acc: 0.9500 - val_loss: 0.3334 - val_acc: 0.8686
#
# Epoch 00106: val_acc did not improve from 0.89423
# Epoch 107/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2023 - acc: 0.9496 - val_loss: 0.2803 - val_acc: 0.8910
#
# Epoch 00107: val_acc did not improve from 0.89423
# Epoch 108/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2001 - acc: 0.9496 - val_loss: 0.2915 - val_acc: 0.8878
#
# Epoch 00108: val_acc did not improve from 0.89423
# Epoch 109/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2004 - acc: 0.9498 - val_loss: 0.2996 - val_acc: 0.8894
#
# Epoch 00109: val_acc did not improve from 0.89423
# Epoch 110/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2003 - acc: 0.9506 - val_loss: 0.3238 - val_acc: 0.8702
#
# Epoch 00110: val_acc did not improve from 0.89423
# Epoch 111/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1994 - acc: 0.9517 - val_loss: 0.3311 - val_acc: 0.8702
#
# Epoch 00111: val_acc did not improve from 0.89423
# Epoch 112/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.2007 - acc: 0.9512 - val_loss: 0.3038 - val_acc: 0.8894
#
# Epoch 00112: val_acc did not improve from 0.89423
# Epoch 113/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1971 - acc: 0.9514 - val_loss: 0.2970 - val_acc: 0.8878
#
# Epoch 00113: val_acc did not improve from 0.89423
# Epoch 114/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1985 - acc: 0.9471 - val_loss: 0.3100 - val_acc: 0.8862
#
# Epoch 00114: val_acc did not improve from 0.89423
# Epoch 115/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1974 - acc: 0.9523 - val_loss: 0.2916 - val_acc: 0.8878
#
# Epoch 00115: val_acc did not improve from 0.89423
# Epoch 116/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1961 - acc: 0.9515 - val_loss: 0.3073 - val_acc: 0.8878
#
# Epoch 00116: val_acc did not improve from 0.89423
# Epoch 117/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1964 - acc: 0.9521 - val_loss: 0.2937 - val_acc: 0.8878
#
# Epoch 00117: val_acc did not improve from 0.89423
# Epoch 118/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1955 - acc: 0.9514 - val_loss: 0.3000 - val_acc: 0.8894
#
# Epoch 00118: val_acc did not improve from 0.89423
# Epoch 119/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1941 - acc: 0.9515 - val_loss: 0.3194 - val_acc: 0.8766
#
# Epoch 00119: val_acc did not improve from 0.89423
# Epoch 120/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1954 - acc: 0.9514 - val_loss: 0.3533 - val_acc: 0.8654
#
# Epoch 00120: val_acc did not improve from 0.89423
# Epoch 121/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1925 - acc: 0.9523 - val_loss: 0.3443 - val_acc: 0.8686
#
# Epoch 00121: val_acc did not improve from 0.89423
# Epoch 122/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1929 - acc: 0.9533 - val_loss: 0.2970 - val_acc: 0.8878
#
# Epoch 00122: val_acc did not improve from 0.89423
# Epoch 123/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1917 - acc: 0.9535 - val_loss: 0.3566 - val_acc: 0.8654
#
# Epoch 00123: val_acc did not improve from 0.89423
# Epoch 124/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1922 - acc: 0.9521 - val_loss: 0.4127 - val_acc: 0.8365
#
# Epoch 00124: val_acc did not improve from 0.89423
# Epoch 125/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1946 - acc: 0.9531 - val_loss: 0.3236 - val_acc: 0.8750
#
# Epoch 00125: val_acc did not improve from 0.89423
# Epoch 126/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1908 - acc: 0.9527 - val_loss: 0.2917 - val_acc: 0.8878
#
# Epoch 00126: val_acc did not improve from 0.89423
# Epoch 127/200
# 5221/5221 [==============================] - 36s 7ms/step - loss: 0.1909 - acc: 0.9531 - val_loss: 0.3357 - val_acc: 0.8734
#
# Epoch 00127: val_acc did not improve from 0.89423
#
#
# Saved history into drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_history

# %%
plot_model_performance(model,
                       test_data=data['test'],
                       test_labels=labels['test'],
                       batch_size=32)
# Out:
# Performances for vgg19_blocks_fc1 model.
#
#
#
# 624/624 [==============================] - 4s 6ms/step
# Loss : 0.28243888647128373
# Score : 0.8942307692307693
#
#
#
# Recall : [0.77777778 0.96410256]
# Precision : [0.92857143 0.87850467]
# Accuracy : [0.29166667 0.6025641 ]

# %%
plot_model_history(SAVE_HISTORY_PATH)
# Out:
# Loading history from drive/My Drive/master1/medical_image_recognition/models/chest_xray/vgg19_blocks_fc1_history
