# %% [markdown]
# # Train a convolutional neural network

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %% [markdown]
# ## Import libraries

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 13 19:35:11 2019

@author: hippolyte
"""

import os
import h5py
import imgaug.augmenters as iaa
import numpy as np
import tensorflow as tf
import imgaug as aug
import datetime
import pickle

from keras.applications import vgg16, vgg19, xception
from keras.models import Model, Sequential, load_model, save_model
from keras.layers import Input, Conv2D, SeparableConv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.engine import InputLayer

from matplotlib import pyplot as plt
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight

# %% [markdown]
# ## Global variables

# %%
################################################################################
### MODIFIABLE VARIABLES
################################################################################
ROOT_PATH = 'drive/My Drive/master1/medical_image_recognition/'
DATASET_NAME = 'cancer_cells'
IMAGE_EXTENSIONS = ['*.jpg', '*.jpeg']

################################################################################
### DON'T CHANGE THESE VARIABLES
################################################################################
DATASET_PATH = ROOT_PATH + 'datasets/' + DATASET_NAME + '/'
ARRAY_PATH   = ROOT_PATH + 'arrays/'   + DATASET_NAME + '/'
MODEL_PATH   = ROOT_PATH + 'models/'   + DATASET_NAME + '/'
# create the directory to save arrays if it doesn't exist
#! mkdir -pv ARRAY_PATH, MODEL_PATH

# get directories and labels
DIRECTORIES = sorted([d for d in os.listdir(DATASET_PATH)])
LABELS = sorted(os.listdir(DATASET_PATH + DIRECTORIES[0]))
# helpers for labels
NUM_LABELS = len(LABELS)
LABEL_MAPPING = {label: code for code, label in enumerate(LABELS)}
# helper for paths
PATHS = {directory: DATASET_PATH + directory + '/' for directory in DIRECTORIES}

# %%
print(DIRECTORIES)
print(LABELS)
print(LABEL_MAPPING)
# Out:
# ['test', 'train', 'val']
# ['cancer', 'normal']
# {'cancer': 0, 'normal': 1}

# %% [markdown]
# ## Fix seeds to have reproducible results
#
# https://keras.io/getting-started/faq/#how-can-i-obtain-reproducible-results-using-keras-during-development

# %%
# the next instructions are used to make results reproducible
SEED = 1234
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(SEED)
tf.set_random_seed(SEED)
aug.seed(SEED)

# %% [markdown]
# ## Data function

# %%
def label_code_to_str(label_code: int) -> str:
    """
    TODO
    """
    for label, code in LABEL_MAPPING.items():
        if label_code == code:
            return label

    raise ValueError('Couldn\'t find the code {} in labels'.format(label_code))

def get_data_dir(directory: str,
                 array_dir: str,
                 height: int=224,
                 width: int=224,
                 channels: int=3):
    """
    TODO
    """
    shape_str = '({},{},{})'.format(height, width, channels)
    filename = array_dir + directory + shape_str + '.h5'
    print('Getting {} images from {}'.format(shape_str, filename))
    
    # some helper variables
    start = datetime.datetime.now()
    
    with h5py.File(filename, 'r') as file:
        # assuming the file contains same amount of image and labels
        num_images = np.ceil(len(file.keys()) / 2).astype(int)

        # define arrays holding data and labels
        data = np.zeros((num_images, height, width, channels), dtype=np.float32)
        labels = np.zeros((num_images, NUM_LABELS), dtype=np.float32)

        # iterate over all images
        # format is x0 y0 for the first image and so on
        for image_index in range(num_images):
            image = file['x' + str(image_index)]
            label = file['y' + str(image_index)]

            data[image_index] = image
            labels[image_index] = label

    # shapes
    print('Data shape : {}\nLabels shape : {}'.format(data.shape, labels.shape))
    
    end = datetime.datetime.now()
    print('Found {} images in {} seconds.'.format(data.shape[0],
                                                 (end-start).seconds))
    
    return data, labels

# %% [markdown]
# ## Convolutional Neural Network functions

# %% [markdown]
# ### Create the network

# %%
def create_vgg19(include_top=True,
                 input_shape=(224, 224, 3),
                 frozen_layers=None):
    """
    TODO
    """
    # create the VGG model
    vgg19_model = vgg19.VGG19(include_top=include_top,
                              weights='imagenet',
                              input_shape=input_shape)
    # model name
    frozen_layers_str = '_'.join(frozen_layers) if frozen_layers else ''
    
    if include_top is True:
        # create a sequential model with corresponding name
        model_name = 'vgg19_' + frozen_layers_str
        model = Sequential(name=model_name)

        # add input layer at bottom
        model.add(InputLayer(input_shape=input_shape))

        # transform the vgg model into sequential
        # taking care to not add the last layer containing the dense layer
        for layer in vgg19_model.layers[:-1]:
            model.add(layer)

        # add last layer
        model.add(Dense(NUM_LABELS, activation='softmax', name='predictions'))
    
    else:
        # create a sequential model with corresponding name
        model_name = 'vgg19_custom_' + frozen_layers_str
        model = Sequential(name=model_name)
        
        # add input layer at bottom
        model.add(InputLayer(input_shape=input_shape))
        
        # add the vgg model to model
        for layer in vgg19_model.layers:
            model.add(layer)
        
        # add classification block
        model.add(Flatten(name='flatten'))
        model.add(Dense(1024, activation='relu', name='fc1')) #1024
        model.add(Dropout(0.7, name='dropout1'))              #notpresent
        model.add(Dense(512, activation='relu', name='fc2'))  #512
        model.add(Dropout(0.5, name='dropout2'))              #notpresent
        model.add(Dense(NUM_LABELS, activation='softmax', name='predictions'))
    
    ###################
    ### FREEZE PART ###
    ###################
    
    if frozen_layers is None:
        print('Everything is trainable.')
    
    else:
        # freeze the first 5 blocks
        if 'blocks' in frozen_layers:
            for i, layer in enumerate(model.layers):
                if layer.name not in ['fc1', 'fc2']:
                    layer.trainable = False

            print('Froze all blocks before classification one.')

        # freeze fc1
        if 'fc1' in frozen_layers:
            model.get_layer('fc1').trainable = False
            print('Froze fc1.')

        # freeze fc2
        if 'fc2' in frozen_layers:
            model.get_layer('fc2').trainable = False
            print('Froze fc2.')
    
    #####################
    ### COMPILE MODEL ###
    #####################
    
    loss_type = 'binary' if NUM_LABELS == 2 else 'categorical'
    loss_type += '_crossentropy'
    optimizer = Adam(lr=1e-6, decay=1e-5)
    
    model.compile(loss=loss_type,
                  metrics=['accuracy'],
                  optimizer=optimizer)
        
    return model

# %% [markdown]
# ### Training function

# %%
def train_model(model,
                train_data,
                train_labels,
                val_data,
                val_labels,
                epoch=50,
                batch_size=32,
                metric='val_loss',
                save_best_only=True,
                save_model_path=None,
                save_weights_only=True,
                stop_after=5,
                save_history=True,
                save_history_path=None,
                class_weight_mapping=None):
    """
    TODO
    """
    # callbacks
    early_stopping = EarlyStopping(patience=stop_after,
                                   monitor=metric,
                                   restore_best_weights=True)
    
    checkpoint = ModelCheckpoint(save_model_path,
                                 monitor=metric,
                                 verbose=1,
                                 save_best_only=save_best_only,
                                 save_weights_only=save_weights_only)

    # here we are, we'll train the model
    history = model.fit(x=train_data,
                        y=train_labels,
                        batch_size=batch_size,
                        epochs=epoch,
                        verbose=1,
                        callbacks=[early_stopping, checkpoint],
                        validation_split=0.0,
                        validation_data=(val_data, val_labels),
                        shuffle=True,
                        class_weight=class_weight_mapping)

    # save history
    if save_history:
        with open(save_history_path, 'wb') as file:
            pickle.dump(history.history, file)
        print('\n\nSaved history into {}'.format(save_history_path))
    
    return model, history

# %% [markdown]
# ### Plot results of the network

# %%
def plot_model_performance(model,
                           test_data,
                           test_labels,
                           batch_size=16):
    """
    TODO
    """
    print('Performances for {} model.'.format(model.name))
    print('\n\n')
    test_loss, test_score = model.evaluate(test_data,
                                           test_labels,
                                           batch_size=16)
    print('Loss : {}'.format(test_loss))
    print('Score : {}'.format(test_score))
    print('\n\n')

    # predictions and groud truth
    preds = model.predict(test_data, batch_size=batch_size)
    preds = np.argmax(preds, axis=-1)
    ground_truth = np.argmax(test_labels, axis=-1)
    
    # confusion matrix
    cm  = confusion_matrix(ground_truth, preds)
    
    # metrics
    recall = np.diag(cm) / np.sum(cm, axis=1)
    precision = np.diag(cm) / np.sum(cm, axis=0)
    accuracy = np.diag(cm) / np.sum(cm)

    print('Recall : {}'.format(recall))
    print('Precision : {}'.format(precision))
    print('Accuracy : {}'.format(accuracy))
    print('\n\n')

    # plot confusion matrix
    plt.figure()
    plot_confusion_matrix(cm,
                          figsize=(12, 8),
                          hide_ticks=True,
                          cmap=plt.cm.Blues)
    plt.xticks(range(NUM_LABELS), LABELS) #, fontsize=16)
    plt.yticks(range(NUM_LABELS), LABELS) #, fontsize=16)
    plt.show()
    
    return preds
    
def plot_model_history(history_path):
    """
    TODO
    """
    print('Loading history from {}'.format(history_path))
    history = pickle.load(open(history_path, 'rb'))

    fig, axes = plt.subplots(1, 2, figsize=(12, 4)) #, constrained_layout=True)

    # accuracy
    axes[0].plot(history['acc'])
    axes[0].plot(history['val_acc'])
    axes[0].set_title('Model Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].legend(['train', 'val'])

    # loss
    axes[1].plot(history['loss'])
    axes[1].plot(history['val_loss'])
    axes[1].set_title('Model Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epochs')
    axes[1].legend(['train', 'val'])
    plt.show()

# %% [markdown]
# ## Let's do it !

# %% [markdown]
# ### Data part

# %%
HEIGHT, WIDTH, CHANNELS = 224, 224, 3

data, labels = dict(), dict()

for directory in DIRECTORIES:
    # get data and labels
    data[directory], labels[directory] = get_data_dir(directory,
                                                      array_dir=ARRAY_PATH,
                                                      height=HEIGHT,
                                                      width=WIDTH,
                                                      channels=CHANNELS)
    
    # get a random index
    ind = np.random.randint(data[directory].shape[0])

    # plot the image with label
    plt.imshow(data[directory][ind])
    img_label = np.argmax(labels[directory][ind])
    img_label_str = label_code_to_str(img_label)
    #plt.title(img_label_str, img_label)
    print('{}({})'.format(img_label, img_label_str))
    plt.show()
# Out:
# Getting (224,224,3) images from drive/My Drive/master1/medical_image_recognition/arrays/cancer_cells/test(224,224,3).h5
# Data shape : (51, 224, 224, 3)
# Labels shape : (51, 2)
# Found 51 images in 0 seconds.
# 0(cancer)
# Getting (224,224,3) images from drive/My Drive/master1/medical_image_recognition/arrays/cancer_cells/train(224,224,3).h5
# Data shape : (145, 224, 224, 3)
# Labels shape : (145, 2)
# Found 145 images in 1 seconds.
# 1(normal)
# Getting (224,224,3) images from drive/My Drive/master1/medical_image_recognition/arrays/cancer_cells/val(224,224,3).h5
# Data shape : (48, 224, 224, 3)
# Labels shape : (48, 2)
# Found 48 images in 0 seconds.
# 1(normal)

# %% [markdown]
# ### CNN creation

# %%
model = create_vgg19(include_top=True,
                     input_shape=(HEIGHT, WIDTH, CHANNELS),
                     frozen_layers=None)

model.summary()
# Out:
# Everything is trainable.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 8194
# =================================================================
# Total params: 139,578,434
# Trainable params: 139,578,434
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### CNN training
# #### USE IT WITH CAUTION, IT CAN TAKE TIME

# %%
import pandas as pd
df = pd.DataFrame(labels['train'])
d = dict(df[0].value_counts())
print(d)
#print(d[0] / d[1])

#LABEL_WEIGHTS = class_weight.compute_class_weight('balanced', =d)
#print(LABEL_WEIGHTS)
# Out:
# {0.0: 73, 1.0: 72}

# %%
CLASS_WEIGHT_MAPPING = None #{0: 1, 1: 0.35}

# %%
SAVE_MODEL_PATH = MODEL_PATH + model.name + '_model.hdf5'
SAVE_HISTORY_PATH = MODEL_PATH + model.name + '_history'

model, history = train_model(model,
                             train_data=data['train'],
                             train_labels=labels['train'],
                             val_data=data['val'],
                             val_labels=labels['val'],
                             epoch=200,
                             batch_size=32,
                             metric='val_acc',
                             save_best_only=True,
                             save_model_path=SAVE_MODEL_PATH,
                             save_weights_only=False,
                             stop_after=100,
                             save_history=True,
                             save_history_path=SAVE_HISTORY_PATH,
                             class_weight_mapping=CLASS_WEIGHT_MAPPING)
# Out:
# Train on 145 samples, validate on 48 samples
# Epoch 1/200
# 145/145 [==============================] - 15s 104ms/step - loss: 0.7174 - acc: 0.4759 - val_loss: 0.7053 - val_acc: 0.5000
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to drive/My Drive/master1/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 2/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.6742 - acc: 0.5310 - val_loss: 0.6956 - val_acc: 0.5417
#
# Epoch 00002: val_acc improved from 0.50000 to 0.54167, saving model to drive/My Drive/master1/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 3/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.6577 - acc: 0.5655 - val_loss: 0.6702 - val_acc: 0.5833
#
# Epoch 00003: val_acc improved from 0.54167 to 0.58333, saving model to drive/My Drive/master1/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 4/200
# 145/145 [==============================] - 6s 43ms/step - loss: 0.6267 - acc: 0.7379 - val_loss: 0.6577 - val_acc: 0.6667
#
# Epoch 00004: val_acc improved from 0.58333 to 0.66667, saving model to drive/My Drive/master1/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 5/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.6189 - acc: 0.6621 - val_loss: 0.6473 - val_acc: 0.6667
#
# Epoch 00005: val_acc did not improve from 0.66667
# Epoch 6/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.5962 - acc: 0.7310 - val_loss: 0.6400 - val_acc: 0.6250
#
# Epoch 00006: val_acc did not improve from 0.66667
# Epoch 7/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.5786 - acc: 0.7379 - val_loss: 0.6219 - val_acc: 0.6250
#
# Epoch 00007: val_acc did not improve from 0.66667
# Epoch 8/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.5596 - acc: 0.7586 - val_loss: 0.6090 - val_acc: 0.6667
#
# Epoch 00008: val_acc did not improve from 0.66667
# Epoch 9/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.5459 - acc: 0.7655 - val_loss: 0.5978 - val_acc: 0.6667
#
# Epoch 00009: val_acc did not improve from 0.66667
# Epoch 10/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.5294 - acc: 0.7517 - val_loss: 0.5967 - val_acc: 0.6458
#
# Epoch 00010: val_acc did not improve from 0.66667
# Epoch 11/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.5128 - acc: 0.7724 - val_loss: 0.5822 - val_acc: 0.6458
#
# Epoch 00011: val_acc did not improve from 0.66667
# Epoch 12/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.4980 - acc: 0.7931 - val_loss: 0.5716 - val_acc: 0.6667
#
# Epoch 00012: val_acc did not improve from 0.66667
# Epoch 13/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.4847 - acc: 0.8000 - val_loss: 0.5669 - val_acc: 0.6667
#
# Epoch 00013: val_acc did not improve from 0.66667
# Epoch 14/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.4716 - acc: 0.8000 - val_loss: 0.5709 - val_acc: 0.6875
#
# Epoch 00014: val_acc improved from 0.66667 to 0.68750, saving model to drive/My Drive/master1/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 15/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.4618 - acc: 0.7931 - val_loss: 0.5574 - val_acc: 0.6667
#
# Epoch 00015: val_acc did not improve from 0.68750
# Epoch 16/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.4479 - acc: 0.8207 - val_loss: 0.5583 - val_acc: 0.6458
#
# Epoch 00016: val_acc did not improve from 0.68750
# Epoch 17/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.4350 - acc: 0.8207 - val_loss: 0.5561 - val_acc: 0.6458
#
# Epoch 00017: val_acc did not improve from 0.68750
# Epoch 18/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.4263 - acc: 0.8276 - val_loss: 0.5504 - val_acc: 0.6458
#
# Epoch 00018: val_acc did not improve from 0.68750
# Epoch 19/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.4106 - acc: 0.8414 - val_loss: 0.5592 - val_acc: 0.6667
#
# Epoch 00019: val_acc did not improve from 0.68750
# Epoch 20/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.4014 - acc: 0.8483 - val_loss: 0.5533 - val_acc: 0.6667
#
# Epoch 00020: val_acc did not improve from 0.68750
# Epoch 21/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.3931 - acc: 0.8552 - val_loss: 0.5528 - val_acc: 0.6667
#
# Epoch 00021: val_acc did not improve from 0.68750
# Epoch 22/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.3769 - acc: 0.8621 - val_loss: 0.5445 - val_acc: 0.6250
#
# Epoch 00022: val_acc did not improve from 0.68750
# Epoch 23/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.3678 - acc: 0.8621 - val_loss: 0.5466 - val_acc: 0.6250
#
# Epoch 00023: val_acc did not improve from 0.68750
# Epoch 24/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.3562 - acc: 0.8621 - val_loss: 0.5529 - val_acc: 0.6667
#
# Epoch 00024: val_acc did not improve from 0.68750
# Epoch 25/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.3441 - acc: 0.8759 - val_loss: 0.5469 - val_acc: 0.6250
#
# Epoch 00025: val_acc did not improve from 0.68750
# Epoch 26/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.3356 - acc: 0.8690 - val_loss: 0.5492 - val_acc: 0.6458
#
# Epoch 00026: val_acc did not improve from 0.68750
# Epoch 27/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.3275 - acc: 0.8759 - val_loss: 0.5651 - val_acc: 0.6875
#
# Epoch 00027: val_acc did not improve from 0.68750
# Epoch 28/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.3169 - acc: 0.8828 - val_loss: 0.5454 - val_acc: 0.6667
#
# Epoch 00028: val_acc did not improve from 0.68750
# Epoch 29/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.3034 - acc: 0.8897 - val_loss: 0.5581 - val_acc: 0.6667
#
# Epoch 00029: val_acc did not improve from 0.68750
# Epoch 30/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.2914 - acc: 0.9034 - val_loss: 0.5534 - val_acc: 0.6458
#
# Epoch 00030: val_acc did not improve from 0.68750
# Epoch 31/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.2787 - acc: 0.9103 - val_loss: 0.5584 - val_acc: 0.6667
#
# Epoch 00031: val_acc did not improve from 0.68750
# Epoch 32/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.2674 - acc: 0.9241 - val_loss: 0.5537 - val_acc: 0.6458
#
# Epoch 00032: val_acc did not improve from 0.68750
# Epoch 33/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.2572 - acc: 0.9448 - val_loss: 0.5563 - val_acc: 0.6250
#
# Epoch 00033: val_acc did not improve from 0.68750
# Epoch 34/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.2489 - acc: 0.9379 - val_loss: 0.5620 - val_acc: 0.6458
#
# Epoch 00034: val_acc did not improve from 0.68750
# Epoch 35/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.2370 - acc: 0.9379 - val_loss: 0.5762 - val_acc: 0.6667
#
# Epoch 00035: val_acc did not improve from 0.68750
# Epoch 36/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.2265 - acc: 0.9448 - val_loss: 0.5711 - val_acc: 0.6458
#
# Epoch 00036: val_acc did not improve from 0.68750
# Epoch 37/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.2206 - acc: 0.9517 - val_loss: 0.5685 - val_acc: 0.6667
#
# Epoch 00037: val_acc did not improve from 0.68750
# Epoch 38/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.2077 - acc: 0.9517 - val_loss: 0.5826 - val_acc: 0.6458
#
# Epoch 00038: val_acc did not improve from 0.68750
# Epoch 39/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1971 - acc: 0.9448 - val_loss: 0.5742 - val_acc: 0.7083
#
# Epoch 00039: val_acc improved from 0.68750 to 0.70833, saving model to drive/My Drive/master1/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 40/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1852 - acc: 0.9724 - val_loss: 0.5856 - val_acc: 0.6667
#
# Epoch 00040: val_acc did not improve from 0.70833
# Epoch 41/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1775 - acc: 0.9586 - val_loss: 0.5940 - val_acc: 0.6458
#
# Epoch 00041: val_acc did not improve from 0.70833
# Epoch 42/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1659 - acc: 0.9724 - val_loss: 0.5825 - val_acc: 0.7500
#
# Epoch 00042: val_acc improved from 0.70833 to 0.75000, saving model to drive/My Drive/master1/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 43/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1606 - acc: 0.9793 - val_loss: 0.5876 - val_acc: 0.7083
#
# Epoch 00043: val_acc did not improve from 0.75000
# Epoch 44/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1496 - acc: 0.9862 - val_loss: 0.5966 - val_acc: 0.6667
#
# Epoch 00044: val_acc did not improve from 0.75000
# Epoch 45/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1409 - acc: 0.9793 - val_loss: 0.5963 - val_acc: 0.7083
#
# Epoch 00045: val_acc did not improve from 0.75000
# Epoch 46/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1345 - acc: 0.9862 - val_loss: 0.6006 - val_acc: 0.7083
#
# Epoch 00046: val_acc did not improve from 0.75000
# Epoch 47/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1249 - acc: 0.9862 - val_loss: 0.6131 - val_acc: 0.6458
#
# Epoch 00047: val_acc did not improve from 0.75000
# Epoch 48/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1189 - acc: 0.9862 - val_loss: 0.6066 - val_acc: 0.7083
#
# Epoch 00048: val_acc did not improve from 0.75000
# Epoch 49/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1131 - acc: 0.9862 - val_loss: 0.6097 - val_acc: 0.7292
#
# Epoch 00049: val_acc did not improve from 0.75000
# Epoch 50/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.1033 - acc: 0.9862 - val_loss: 0.6371 - val_acc: 0.6667
#
# Epoch 00050: val_acc did not improve from 0.75000
# Epoch 51/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0985 - acc: 0.9862 - val_loss: 0.6292 - val_acc: 0.6875
#
# Epoch 00051: val_acc did not improve from 0.75000
# Epoch 52/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0932 - acc: 0.9931 - val_loss: 0.6272 - val_acc: 0.7500
#
# Epoch 00052: val_acc did not improve from 0.75000
# Epoch 53/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0846 - acc: 0.9931 - val_loss: 0.6507 - val_acc: 0.6667
#
# Epoch 00053: val_acc did not improve from 0.75000
# Epoch 54/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0802 - acc: 0.9931 - val_loss: 0.6480 - val_acc: 0.6875
#
# Epoch 00054: val_acc did not improve from 0.75000
# Epoch 55/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0729 - acc: 0.9931 - val_loss: 0.6492 - val_acc: 0.6875
#
# Epoch 00055: val_acc did not improve from 0.75000
# Epoch 56/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0686 - acc: 0.9931 - val_loss: 0.6568 - val_acc: 0.6875
#
# Epoch 00056: val_acc did not improve from 0.75000
# Epoch 57/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0636 - acc: 1.0000 - val_loss: 0.6574 - val_acc: 0.7083
#
# Epoch 00057: val_acc did not improve from 0.75000
# Epoch 58/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0598 - acc: 1.0000 - val_loss: 0.6800 - val_acc: 0.6875
#
# Epoch 00058: val_acc did not improve from 0.75000
# Epoch 59/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0551 - acc: 1.0000 - val_loss: 0.6741 - val_acc: 0.6875
#
# Epoch 00059: val_acc did not improve from 0.75000
# Epoch 60/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0512 - acc: 1.0000 - val_loss: 0.6792 - val_acc: 0.7083
#
# Epoch 00060: val_acc did not improve from 0.75000
# Epoch 61/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0468 - acc: 1.0000 - val_loss: 0.6975 - val_acc: 0.6667
#
# Epoch 00061: val_acc did not improve from 0.75000
# Epoch 62/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0441 - acc: 1.0000 - val_loss: 0.7000 - val_acc: 0.6875
#
# Epoch 00062: val_acc did not improve from 0.75000
# Epoch 63/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0408 - acc: 1.0000 - val_loss: 0.7015 - val_acc: 0.6875
#
# Epoch 00063: val_acc did not improve from 0.75000
# Epoch 64/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0380 - acc: 1.0000 - val_loss: 0.7150 - val_acc: 0.6667
#
# Epoch 00064: val_acc did not improve from 0.75000
# Epoch 65/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0349 - acc: 1.0000 - val_loss: 0.7173 - val_acc: 0.6875
#
# Epoch 00065: val_acc did not improve from 0.75000
# Epoch 66/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0341 - acc: 1.0000 - val_loss: 0.7223 - val_acc: 0.7083
#
# Epoch 00066: val_acc did not improve from 0.75000
# Epoch 67/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0312 - acc: 1.0000 - val_loss: 0.7432 - val_acc: 0.6875
#
# Epoch 00067: val_acc did not improve from 0.75000
# Epoch 68/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0290 - acc: 1.0000 - val_loss: 0.7407 - val_acc: 0.6875
#
# Epoch 00068: val_acc did not improve from 0.75000
# Epoch 69/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0266 - acc: 1.0000 - val_loss: 0.7523 - val_acc: 0.6875
#
# Epoch 00069: val_acc did not improve from 0.75000
# Epoch 70/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0243 - acc: 1.0000 - val_loss: 0.7565 - val_acc: 0.7083
#
# Epoch 00070: val_acc did not improve from 0.75000
# Epoch 71/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0234 - acc: 1.0000 - val_loss: 0.7659 - val_acc: 0.6875
#
# Epoch 00071: val_acc did not improve from 0.75000
# Epoch 72/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0213 - acc: 1.0000 - val_loss: 0.7743 - val_acc: 0.6875
#
# Epoch 00072: val_acc did not improve from 0.75000
# Epoch 73/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0203 - acc: 1.0000 - val_loss: 0.7809 - val_acc: 0.6875
#
# Epoch 00073: val_acc did not improve from 0.75000
# Epoch 74/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0188 - acc: 1.0000 - val_loss: 0.7949 - val_acc: 0.6875
#
# Epoch 00074: val_acc did not improve from 0.75000
# Epoch 75/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0179 - acc: 1.0000 - val_loss: 0.7998 - val_acc: 0.6875
#
# Epoch 00075: val_acc did not improve from 0.75000
# Epoch 76/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0166 - acc: 1.0000 - val_loss: 0.8024 - val_acc: 0.7083
#
# Epoch 00076: val_acc did not improve from 0.75000
# Epoch 77/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0159 - acc: 1.0000 - val_loss: 0.8084 - val_acc: 0.7083
#
# Epoch 00077: val_acc did not improve from 0.75000
# Epoch 78/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0149 - acc: 1.0000 - val_loss: 0.8196 - val_acc: 0.6875
#
# Epoch 00078: val_acc did not improve from 0.75000
# Epoch 79/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0140 - acc: 1.0000 - val_loss: 0.8253 - val_acc: 0.6875
#
# Epoch 00079: val_acc did not improve from 0.75000
# Epoch 80/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0134 - acc: 1.0000 - val_loss: 0.8301 - val_acc: 0.7083
#
# Epoch 00080: val_acc did not improve from 0.75000
# Epoch 81/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0126 - acc: 1.0000 - val_loss: 0.8409 - val_acc: 0.6667
#
# Epoch 00081: val_acc did not improve from 0.75000
# Epoch 82/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0119 - acc: 1.0000 - val_loss: 0.8438 - val_acc: 0.6875
#
# Epoch 00082: val_acc did not improve from 0.75000
# Epoch 83/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0111 - acc: 1.0000 - val_loss: 0.8479 - val_acc: 0.7083
#
# Epoch 00083: val_acc did not improve from 0.75000
# Epoch 84/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0108 - acc: 1.0000 - val_loss: 0.8540 - val_acc: 0.7083
#
# Epoch 00084: val_acc did not improve from 0.75000
# Epoch 85/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0102 - acc: 1.0000 - val_loss: 0.8611 - val_acc: 0.7083
#
# Epoch 00085: val_acc did not improve from 0.75000
# Epoch 86/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0099 - acc: 1.0000 - val_loss: 0.8708 - val_acc: 0.6667
#
# Epoch 00086: val_acc did not improve from 0.75000
# Epoch 87/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0095 - acc: 1.0000 - val_loss: 0.8726 - val_acc: 0.7083
#
# Epoch 00087: val_acc did not improve from 0.75000
# Epoch 88/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0089 - acc: 1.0000 - val_loss: 0.8802 - val_acc: 0.6875
#
# Epoch 00088: val_acc did not improve from 0.75000
# Epoch 89/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0086 - acc: 1.0000 - val_loss: 0.8844 - val_acc: 0.7083
#
# Epoch 00089: val_acc did not improve from 0.75000
# Epoch 90/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0080 - acc: 1.0000 - val_loss: 0.8900 - val_acc: 0.7083
#
# Epoch 00090: val_acc did not improve from 0.75000
# Epoch 91/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0077 - acc: 1.0000 - val_loss: 0.8969 - val_acc: 0.6875
#
# Epoch 00091: val_acc did not improve from 0.75000
# Epoch 92/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0074 - acc: 1.0000 - val_loss: 0.9013 - val_acc: 0.6875
#
# Epoch 00092: val_acc did not improve from 0.75000
# Epoch 93/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0071 - acc: 1.0000 - val_loss: 0.9037 - val_acc: 0.7083
#
# Epoch 00093: val_acc did not improve from 0.75000
# Epoch 94/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0068 - acc: 1.0000 - val_loss: 0.9071 - val_acc: 0.7083
#
# Epoch 00094: val_acc did not improve from 0.75000
# Epoch 95/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0066 - acc: 1.0000 - val_loss: 0.9123 - val_acc: 0.7083
#
# Epoch 00095: val_acc did not improve from 0.75000
# Epoch 96/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 0.9185 - val_acc: 0.7083
#
# Epoch 00096: val_acc did not improve from 0.75000
# Epoch 97/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0061 - acc: 1.0000 - val_loss: 0.9256 - val_acc: 0.6875
#
# Epoch 00097: val_acc did not improve from 0.75000
# Epoch 98/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0059 - acc: 1.0000 - val_loss: 0.9287 - val_acc: 0.7083
#
# Epoch 00098: val_acc did not improve from 0.75000
# Epoch 99/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0056 - acc: 1.0000 - val_loss: 0.9322 - val_acc: 0.7083
#
# Epoch 00099: val_acc did not improve from 0.75000
# Epoch 100/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0054 - acc: 1.0000 - val_loss: 0.9377 - val_acc: 0.7083
#
# Epoch 00100: val_acc did not improve from 0.75000
# Epoch 101/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0052 - acc: 1.0000 - val_loss: 0.9428 - val_acc: 0.7083
#
# Epoch 00101: val_acc did not improve from 0.75000
# Epoch 102/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0050 - acc: 1.0000 - val_loss: 0.9483 - val_acc: 0.7083
#
# Epoch 00102: val_acc did not improve from 0.75000
# Epoch 103/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0048 - acc: 1.0000 - val_loss: 0.9525 - val_acc: 0.7083
#
# Epoch 00103: val_acc did not improve from 0.75000
# Epoch 104/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0046 - acc: 1.0000 - val_loss: 0.9575 - val_acc: 0.7083
#
# Epoch 00104: val_acc did not improve from 0.75000
# Epoch 105/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0045 - acc: 1.0000 - val_loss: 0.9628 - val_acc: 0.7083
#
# Epoch 00105: val_acc did not improve from 0.75000
# Epoch 106/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0043 - acc: 1.0000 - val_loss: 0.9682 - val_acc: 0.7083
#
# Epoch 00106: val_acc did not improve from 0.75000
# Epoch 107/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0042 - acc: 1.0000 - val_loss: 0.9730 - val_acc: 0.7083
#
# Epoch 00107: val_acc did not improve from 0.75000
# Epoch 108/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0040 - acc: 1.0000 - val_loss: 0.9789 - val_acc: 0.7083
#
# Epoch 00108: val_acc did not improve from 0.75000
# Epoch 109/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0039 - acc: 1.0000 - val_loss: 0.9833 - val_acc: 0.7083
#
# Epoch 00109: val_acc did not improve from 0.75000
# Epoch 110/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0038 - acc: 1.0000 - val_loss: 0.9872 - val_acc: 0.7083
#
# Epoch 00110: val_acc did not improve from 0.75000
# Epoch 111/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0036 - acc: 1.0000 - val_loss: 0.9912 - val_acc: 0.7083
#
# Epoch 00111: val_acc did not improve from 0.75000
# Epoch 112/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.9960 - val_acc: 0.7083
#
# Epoch 00112: val_acc did not improve from 0.75000
# Epoch 113/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0034 - acc: 1.0000 - val_loss: 1.0010 - val_acc: 0.7083
#
# Epoch 00113: val_acc did not improve from 0.75000
# Epoch 114/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0033 - acc: 1.0000 - val_loss: 1.0063 - val_acc: 0.7083
#
# Epoch 00114: val_acc did not improve from 0.75000
# Epoch 115/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 1.0108 - val_acc: 0.7083
#
# Epoch 00115: val_acc did not improve from 0.75000
# Epoch 116/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0031 - acc: 1.0000 - val_loss: 1.0158 - val_acc: 0.7083
#
# Epoch 00116: val_acc did not improve from 0.75000
# Epoch 117/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0030 - acc: 1.0000 - val_loss: 1.0216 - val_acc: 0.7083
#
# Epoch 00117: val_acc did not improve from 0.75000
# Epoch 118/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0030 - acc: 1.0000 - val_loss: 1.0258 - val_acc: 0.7083
#
# Epoch 00118: val_acc did not improve from 0.75000
# Epoch 119/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0028 - acc: 1.0000 - val_loss: 1.0278 - val_acc: 0.7083
#
# Epoch 00119: val_acc did not improve from 0.75000
# Epoch 120/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0028 - acc: 1.0000 - val_loss: 1.0324 - val_acc: 0.7083
#
# Epoch 00120: val_acc did not improve from 0.75000
# Epoch 121/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0027 - acc: 1.0000 - val_loss: 1.0360 - val_acc: 0.7083
#
# Epoch 00121: val_acc did not improve from 0.75000
# Epoch 122/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 1.0413 - val_acc: 0.7083
#
# Epoch 00122: val_acc did not improve from 0.75000
# Epoch 123/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0025 - acc: 1.0000 - val_loss: 1.0447 - val_acc: 0.7083
#
# Epoch 00123: val_acc did not improve from 0.75000
# Epoch 124/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0024 - acc: 1.0000 - val_loss: 1.0474 - val_acc: 0.7083
#
# Epoch 00124: val_acc did not improve from 0.75000
# Epoch 125/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 1.0505 - val_acc: 0.7083
#
# Epoch 00125: val_acc did not improve from 0.75000
# Epoch 126/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 1.0538 - val_acc: 0.7083
#
# Epoch 00126: val_acc did not improve from 0.75000
# Epoch 127/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0022 - acc: 1.0000 - val_loss: 1.0574 - val_acc: 0.7083
#
# Epoch 00127: val_acc did not improve from 0.75000
# Epoch 128/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 1.0609 - val_acc: 0.7083
#
# Epoch 00128: val_acc did not improve from 0.75000
# Epoch 129/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 1.0641 - val_acc: 0.7083
#
# Epoch 00129: val_acc did not improve from 0.75000
# Epoch 130/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 1.0673 - val_acc: 0.7083
#
# Epoch 00130: val_acc did not improve from 0.75000
# Epoch 131/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 1.0711 - val_acc: 0.7083
#
# Epoch 00131: val_acc did not improve from 0.75000
# Epoch 132/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 1.0746 - val_acc: 0.7083
#
# Epoch 00132: val_acc did not improve from 0.75000
# Epoch 133/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 1.0790 - val_acc: 0.7083
#
# Epoch 00133: val_acc did not improve from 0.75000
# Epoch 134/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 1.0826 - val_acc: 0.7083
#
# Epoch 00134: val_acc did not improve from 0.75000
# Epoch 135/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 1.0850 - val_acc: 0.7083
#
# Epoch 00135: val_acc did not improve from 0.75000
# Epoch 136/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 1.0878 - val_acc: 0.7083
#
# Epoch 00136: val_acc did not improve from 0.75000
# Epoch 137/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 1.0899 - val_acc: 0.7083
#
# Epoch 00137: val_acc did not improve from 0.75000
# Epoch 138/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 1.0922 - val_acc: 0.7083
#
# Epoch 00138: val_acc did not improve from 0.75000
# Epoch 139/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.0944 - val_acc: 0.7083
#
# Epoch 00139: val_acc did not improve from 0.75000
# Epoch 140/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.0969 - val_acc: 0.7083
#
# Epoch 00140: val_acc did not improve from 0.75000
# Epoch 141/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 1.0997 - val_acc: 0.7083
#
# Epoch 00141: val_acc did not improve from 0.75000
# Epoch 142/200
# 145/145 [==============================] - 6s 42ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 1.1032 - val_acc: 0.7083
#
# Epoch 00142: val_acc did not improve from 0.75000
#
#
# Saved history into drive/My Drive/master1/medical_image_recognition/models/cancer_cells/vgg19__history

# %%
preds = plot_model_performance(model,
                               test_data=data['test'],
                               test_labels=labels['test'],
                               batch_size=32)

from sklearn.metrics import classification_report
print(classification_report(labels['test'],
                            preds,
                            target_names=LABELS))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-29d38296064a> in <module>()
# ----> 1 preds = plot_model_performance(model,
#       2                                test_data=data['test'],
#       3                                test_labels=labels['test'],
#       4                                batch_size=32)
#       5
#
# NameError: name 'model' is not defined

# %%
plot_model_history(SAVE_HISTORY_PATH)
# Out:
# Loading history from drive/My Drive/master1/medical_image_recognition/models/cancer_cells/vgg19__history
