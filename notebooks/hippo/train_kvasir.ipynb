# %%
from google.colab import drive, files
drive.mount('drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at drive

# %%
from keras import applications
from keras import optimizers
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense, InputLayer
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
ROOT_PATH    = 'drive/My Drive/master1/medical_image_recognition/'
DATASET_NAME = 'kvasir_v2'
DATASET_PATH = ROOT_PATH + 'datasets/' + DATASET_NAME + '/'
MODEL_PATH   = ROOT_PATH + 'models/'   + DATASET_NAME + '/'

# %%
def get_generator(directory,
                  image_shape=(224, 224),
                  batch_size=32,
                  should_augment=False,
                  data_gen_args=None):
    
    # only rescale
    if should_augment is False:
        image_gen = ImageDataGenerator(rescale=(1./255))
    
    # use dictionary to define augmentations
    else:
        if data_gen_args is None:
            data_gen_args = dict(rescale=1./255,
                                 shear_range=0.2,
                                 zoom_range=0.2,
                                 horizontal_flip=True)
        
        image_gen = ImageDataGenerator(**data_gen_args)
    
    return image_gen.flow_from_directory(directory,
                                         target_size=image_shape,
                                         batch_size=batch_size)

# %%
HEIGHT, WIDTH, CHANNELS = 224, 224, 3
BATCH_SIZE = 32

train_generator = get_generator(DATASET_PATH + 'train',
                                batch_size=BATCH_SIZE,
                                should_augment=True)

test_generator = get_generator(DATASET_PATH + 'val',
                               batch_size=BATCH_SIZE)
# Out:
# Found 4800 images belonging to 8 classes.
# Found 1600 images belonging to 8 classes.

# %%
def build_model(image_shape,
                classes,
                num_layers_to_freeze=21,
                base_model_weights_path=None,
                top_model_weights_path=None):
    
    model_name = f'vgg19_{num_layers_to_freeze}'
    
    # build the base model
    if base_model_weights_path is None:
        base_model_weights_path = 'imagenet'
    base_model = applications.vgg19.VGG19(input_shape=image_shape,
                                          weights=base_model_weights_path,
                                          include_top=False)
    print('Load VGG19 as base model')
    
    # load base model weights
    #base_model.load_weights(base_model_weights_path)
    
    # adding classification block on top of base model
    x = Flatten(input_shape=image_shape, name='flatten')(base_model.output)
    x = Dense(512, activation='relu', name='fc1')(x)
    x = Dropout(0.5, name='dropout1')(x)
    x = Dense(216, activation='relu', name='fc2')(x)
    x = Dropout(0.5, name='dropout2')(x)
    x = Dense(classes, activation='softmax', name='predictions')(x)
    
    # combine both
    model = Model(inputs=base_model.input, outputs=x, name=model_name)
    
    # load top model weights
    #model.load_weights(top_model_weights_path)
    
    # freeze layers
    for i, layer in enumerate(model.layers):
        if i <= num_layers_to_freeze:
            layer.trainable = False
        else:
            layer.trainable = True
            print(f'Layer {i} {layer.name} is trainable')

    # compile model
    loss_type = 'binary_' if classes == 2 else 'categorical_'
    loss_type += 'crossentropy'
    model.compile(loss=loss_type,
                  optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
                  metrics=['accuracy'])
    
    print('Model compiled')
    return model

# %%
BASE_MODEL_WEIGHTS_PATH = ROOT_PATH + 'models/vgg19_weights_no_top.h5'

model = build_model(image_shape=(HEIGHT, WIDTH, CHANNELS), classes=8)
model.summary()

# %%
# fine-tune the model
EPOCHS = 300
TRAIN_LEN = train_generator.n
TEST_LEN = test_generator.n
CLASS_WEIGHT = None #{0: 1.0, 1: 0.4}

SAVE_HISTORY_PATH = MODEL_PATH + model.name + '.history'
SAVE_MODEL_PATH   = MODEL_PATH + model.name + '.model'

import pickle

def train_model(save_model_path,
                save_history_path,
                save_history=True):
    
    early_stopping = EarlyStopping(patience=20,
                                   monitor='val_loss',
                                   restore_best_weights=True)

    checkpoint = ModelCheckpoint(save_model_path,
                                 monitor='val_loss',
                                 verbose=1,
                                 save_best_only=True,
                                 save_weights_only=False)

    #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
    #                              patience=5, min_lr=0.001)

    history = model.fit_generator(
        train_generator,
        steps_per_epoch=TRAIN_LEN //  BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=test_generator,
        validation_steps=TEST_LEN // BATCH_SIZE,
        verbose=1,
        callbacks=[early_stopping, checkpoint],
        class_weight=CLASS_WEIGHT)

    # save history
    if save_history:
        with open(save_history_path, 'wb') as file:
            pickle.dump(history.history, file)
        print(f'\n\nSaved history into {save_history_path}')

# %%
train_model(save_model_path=SAVE_MODEL_PATH,
            save_history_path=SAVE_HISTORY_PATH)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/300
# 150/150 [==============================] - 1454s 10s/step - loss: 2.1941 - acc: 0.1727 - val_loss: 1.8496 - val_acc: 0.3438
#
# Epoch 00001: val_loss improved from inf to 1.84964, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 2/300
# 150/150 [==============================] - 188s 1s/step - loss: 1.9385 - acc: 0.2263 - val_loss: 1.7011 - val_acc: 0.3575
#
# Epoch 00002: val_loss improved from 1.84964 to 1.70110, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 3/300
# 150/150 [==============================] - 193s 1s/step - loss: 1.8321 - acc: 0.2619 - val_loss: 1.5892 - val_acc: 0.4725
#
# Epoch 00003: val_loss improved from 1.70110 to 1.58924, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 4/300
# 150/150 [==============================] - 190s 1s/step - loss: 1.7341 - acc: 0.3054 - val_loss: 1.4690 - val_acc: 0.5044
#
# Epoch 00004: val_loss improved from 1.58924 to 1.46896, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 5/300
# 150/150 [==============================] - 190s 1s/step - loss: 1.6724 - acc: 0.3210 - val_loss: 1.4068 - val_acc: 0.4944
#
# Epoch 00005: val_loss improved from 1.46896 to 1.40680, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 6/300
# 150/150 [==============================] - 193s 1s/step - loss: 1.6007 - acc: 0.3398 - val_loss: 1.3453 - val_acc: 0.5387
#
# Epoch 00006: val_loss improved from 1.40680 to 1.34525, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 7/300
# 150/150 [==============================] - 193s 1s/step - loss: 1.5447 - acc: 0.3583 - val_loss: 1.2946 - val_acc: 0.5188
#
# Epoch 00007: val_loss improved from 1.34525 to 1.29462, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 8/300
# 150/150 [==============================] - 191s 1s/step - loss: 1.5079 - acc: 0.3544 - val_loss: 1.2557 - val_acc: 0.5125
#
# Epoch 00008: val_loss improved from 1.29462 to 1.25570, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 9/300
# 150/150 [==============================] - 193s 1s/step - loss: 1.4648 - acc: 0.3954 - val_loss: 1.2192 - val_acc: 0.5469
#
# Epoch 00009: val_loss improved from 1.25570 to 1.21924, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 10/300
# 150/150 [==============================] - 191s 1s/step - loss: 1.4329 - acc: 0.4004 - val_loss: 1.1945 - val_acc: 0.5162
#
# Epoch 00010: val_loss improved from 1.21924 to 1.19455, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 11/300
# 150/150 [==============================] - 192s 1s/step - loss: 1.3906 - acc: 0.4229 - val_loss: 1.1337 - val_acc: 0.5856
#
# Epoch 00011: val_loss improved from 1.19455 to 1.13373, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 12/300
# 150/150 [==============================] - 192s 1s/step - loss: 1.3844 - acc: 0.4221 - val_loss: 1.1085 - val_acc: 0.5919
#
# Epoch 00012: val_loss improved from 1.13373 to 1.10853, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 13/300
# 150/150 [==============================] - 195s 1s/step - loss: 1.3463 - acc: 0.4285 - val_loss: 1.0939 - val_acc: 0.5631
#
# Epoch 00013: val_loss improved from 1.10853 to 1.09387, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 14/300
# 150/150 [==============================] - 194s 1s/step - loss: 1.3142 - acc: 0.4456 - val_loss: 1.0647 - val_acc: 0.5837
#
# Epoch 00014: val_loss improved from 1.09387 to 1.06472, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 15/300
# 150/150 [==============================] - 195s 1s/step - loss: 1.3077 - acc: 0.4529 - val_loss: 1.0452 - val_acc: 0.5938
#
# Epoch 00015: val_loss improved from 1.06472 to 1.04522, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 16/300
# 150/150 [==============================] - 195s 1s/step - loss: 1.2686 - acc: 0.4623 - val_loss: 1.0296 - val_acc: 0.5844
#
# Epoch 00016: val_loss improved from 1.04522 to 1.02961, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 17/300
# 150/150 [==============================] - 194s 1s/step - loss: 1.2448 - acc: 0.4704 - val_loss: 1.0175 - val_acc: 0.5887
#
# Epoch 00017: val_loss improved from 1.02961 to 1.01750, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 18/300
# 150/150 [==============================] - 195s 1s/step - loss: 1.2358 - acc: 0.4892 - val_loss: 0.9864 - val_acc: 0.6112
#
# Epoch 00018: val_loss improved from 1.01750 to 0.98638, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 19/300
# 150/150 [==============================] - 192s 1s/step - loss: 1.2061 - acc: 0.4858 - val_loss: 0.9661 - val_acc: 0.6081
#
# Epoch 00019: val_loss improved from 0.98638 to 0.96613, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 20/300
# 150/150 [==============================] - 195s 1s/step - loss: 1.1953 - acc: 0.4873 - val_loss: 0.9695 - val_acc: 0.6062
#
# Epoch 00020: val_loss did not improve from 0.96613
# Epoch 21/300
# 150/150 [==============================] - 195s 1s/step - loss: 1.1946 - acc: 0.4883 - val_loss: 0.9444 - val_acc: 0.6062
#
# Epoch 00021: val_loss improved from 0.96613 to 0.94439, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 22/300
# 150/150 [==============================] - 196s 1s/step - loss: 1.1695 - acc: 0.4992 - val_loss: 0.9242 - val_acc: 0.6181
#
# Epoch 00022: val_loss improved from 0.94439 to 0.92420, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 23/300
# 150/150 [==============================] - 238s 2s/step - loss: 1.1370 - acc: 0.5150 - val_loss: 0.8917 - val_acc: 0.6512
#
# Epoch 00023: val_loss improved from 0.92420 to 0.89169, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 24/300
# 150/150 [==============================] - 206s 1s/step - loss: 1.1332 - acc: 0.5154 - val_loss: 0.9068 - val_acc: 0.6381
#
# Epoch 00024: val_loss did not improve from 0.89169
# Epoch 25/300
# 150/150 [==============================] - 196s 1s/step - loss: 1.1251 - acc: 0.5133 - val_loss: 0.8722 - val_acc: 0.6569
#
# Epoch 00025: val_loss improved from 0.89169 to 0.87216, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 26/300
# 150/150 [==============================] - 200s 1s/step - loss: 1.1144 - acc: 0.5183 - val_loss: 0.8728 - val_acc: 0.6431
#
# Epoch 00026: val_loss did not improve from 0.87216
# Epoch 27/300
# 150/150 [==============================] - 196s 1s/step - loss: 1.0807 - acc: 0.5387 - val_loss: 0.8606 - val_acc: 0.6425
#
# Epoch 00027: val_loss improved from 0.87216 to 0.86064, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 28/300
# 150/150 [==============================] - 198s 1s/step - loss: 1.0832 - acc: 0.5329 - val_loss: 0.8471 - val_acc: 0.6856
#
# Epoch 00028: val_loss improved from 0.86064 to 0.84710, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 29/300
# 150/150 [==============================] - 200s 1s/step - loss: 1.0571 - acc: 0.5485 - val_loss: 0.8302 - val_acc: 0.6900
#
# Epoch 00029: val_loss improved from 0.84710 to 0.83016, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 30/300
# 150/150 [==============================] - 199s 1s/step - loss: 1.0605 - acc: 0.5425 - val_loss: 0.8410 - val_acc: 0.6794
#
# Epoch 00030: val_loss did not improve from 0.83016
# Epoch 31/300
# 150/150 [==============================] - 194s 1s/step - loss: 1.0410 - acc: 0.5577 - val_loss: 0.8197 - val_acc: 0.6594
#
# Epoch 00031: val_loss improved from 0.83016 to 0.81966, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 32/300
# 150/150 [==============================] - 193s 1s/step - loss: 1.0190 - acc: 0.5627 - val_loss: 0.8179 - val_acc: 0.6556
#
# Epoch 00032: val_loss improved from 0.81966 to 0.81787, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 33/300
# 150/150 [==============================] - 196s 1s/step - loss: 1.0320 - acc: 0.5527 - val_loss: 0.8030 - val_acc: 0.6475
#
# Epoch 00033: val_loss improved from 0.81787 to 0.80305, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 34/300
# 150/150 [==============================] - 199s 1s/step - loss: 0.9953 - acc: 0.5790 - val_loss: 0.8024 - val_acc: 0.6644
#
# Epoch 00034: val_loss improved from 0.80305 to 0.80243, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 35/300
# 150/150 [==============================] - 199s 1s/step - loss: 0.9960 - acc: 0.5690 - val_loss: 0.7812 - val_acc: 0.7000
#
# Epoch 00035: val_loss improved from 0.80243 to 0.78121, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 36/300
# 150/150 [==============================] - 201s 1s/step - loss: 0.9917 - acc: 0.5740 - val_loss: 0.7763 - val_acc: 0.6831
#
# Epoch 00036: val_loss improved from 0.78121 to 0.77634, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 37/300
# 150/150 [==============================] - 198s 1s/step - loss: 0.9824 - acc: 0.5706 - val_loss: 0.7820 - val_acc: 0.6925
#
# Epoch 00037: val_loss did not improve from 0.77634
# Epoch 38/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.9795 - acc: 0.5679 - val_loss: 0.7937 - val_acc: 0.6706
#
# Epoch 00038: val_loss did not improve from 0.77634
# Epoch 39/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.9469 - acc: 0.5885 - val_loss: 0.7671 - val_acc: 0.6900
#
# Epoch 00039: val_loss improved from 0.77634 to 0.76711, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 40/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.9439 - acc: 0.5871 - val_loss: 0.7584 - val_acc: 0.6913
#
# Epoch 00040: val_loss improved from 0.76711 to 0.75843, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 41/300
# 150/150 [==============================] - 200s 1s/step - loss: 0.9528 - acc: 0.5915 - val_loss: 0.7478 - val_acc: 0.7056
#
# Epoch 00041: val_loss improved from 0.75843 to 0.74781, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 42/300
# 150/150 [==============================] - 200s 1s/step - loss: 0.9413 - acc: 0.5906 - val_loss: 0.7255 - val_acc: 0.7281
#
# Epoch 00042: val_loss improved from 0.74781 to 0.72551, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 43/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.9297 - acc: 0.6000 - val_loss: 0.7323 - val_acc: 0.7100
#
# Epoch 00043: val_loss did not improve from 0.72551
# Epoch 44/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.9300 - acc: 0.5938 - val_loss: 0.7447 - val_acc: 0.6800
#
# Epoch 00044: val_loss did not improve from 0.72551
# Epoch 45/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.9176 - acc: 0.6152 - val_loss: 0.7311 - val_acc: 0.7106
#
# Epoch 00045: val_loss did not improve from 0.72551
# Epoch 46/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.9212 - acc: 0.6012 - val_loss: 0.7347 - val_acc: 0.6863
#
# Epoch 00046: val_loss did not improve from 0.72551
# Epoch 47/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.9075 - acc: 0.6108 - val_loss: 0.7048 - val_acc: 0.7119
#
# Epoch 00047: val_loss improved from 0.72551 to 0.70480, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 48/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.8853 - acc: 0.6150 - val_loss: 0.7184 - val_acc: 0.7087
#
# Epoch 00048: val_loss did not improve from 0.70480
# Epoch 49/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.8904 - acc: 0.6160 - val_loss: 0.6938 - val_acc: 0.7119
#
# Epoch 00049: val_loss improved from 0.70480 to 0.69382, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 50/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.8911 - acc: 0.6146 - val_loss: 0.7020 - val_acc: 0.7019
#
# Epoch 00050: val_loss did not improve from 0.69382
# Epoch 51/300
# 150/150 [==============================] - 198s 1s/step - loss: 0.8871 - acc: 0.6158 - val_loss: 0.6881 - val_acc: 0.7131
#
# Epoch 00051: val_loss improved from 0.69382 to 0.68807, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 52/300
# 150/150 [==============================] - 197s 1s/step - loss: 0.8664 - acc: 0.6262 - val_loss: 0.6774 - val_acc: 0.7375
#
# Epoch 00052: val_loss improved from 0.68807 to 0.67735, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 53/300
# 150/150 [==============================] - 199s 1s/step - loss: 0.8678 - acc: 0.6300 - val_loss: 0.6779 - val_acc: 0.7144
#
# Epoch 00053: val_loss did not improve from 0.67735
# Epoch 54/300
# 150/150 [==============================] - 197s 1s/step - loss: 0.8599 - acc: 0.6300 - val_loss: 0.6984 - val_acc: 0.7137
#
# Epoch 00054: val_loss did not improve from 0.67735
# Epoch 55/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.8595 - acc: 0.6329 - val_loss: 0.6787 - val_acc: 0.7106
#
# Epoch 00055: val_loss did not improve from 0.67735
# Epoch 56/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.8551 - acc: 0.6292 - val_loss: 0.6719 - val_acc: 0.7181
#
# Epoch 00056: val_loss improved from 0.67735 to 0.67193, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 57/300
# 150/150 [==============================] - 198s 1s/step - loss: 0.8585 - acc: 0.6340 - val_loss: 0.6711 - val_acc: 0.7269
#
# Epoch 00057: val_loss improved from 0.67193 to 0.67115, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 58/300
# 150/150 [==============================] - 199s 1s/step - loss: 0.8581 - acc: 0.6300 - val_loss: 0.6715 - val_acc: 0.7300
#
# Epoch 00058: val_loss did not improve from 0.67115
# Epoch 59/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.8413 - acc: 0.6323 - val_loss: 0.6737 - val_acc: 0.7181
#
# Epoch 00059: val_loss did not improve from 0.67115
# Epoch 60/300
# 150/150 [==============================] - 197s 1s/step - loss: 0.8191 - acc: 0.6400 - val_loss: 0.6849 - val_acc: 0.7000
#
# Epoch 00060: val_loss did not improve from 0.67115
# Epoch 61/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.8320 - acc: 0.6415 - val_loss: 0.6607 - val_acc: 0.7262
#
# Epoch 00061: val_loss improved from 0.67115 to 0.66070, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 62/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.8284 - acc: 0.6431 - val_loss: 0.6690 - val_acc: 0.7219
#
# Epoch 00062: val_loss did not improve from 0.66070
# Epoch 63/300
# 150/150 [==============================] - 197s 1s/step - loss: 0.8220 - acc: 0.6458 - val_loss: 0.6543 - val_acc: 0.7362
#
# Epoch 00063: val_loss improved from 0.66070 to 0.65433, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 64/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.8236 - acc: 0.6494 - val_loss: 0.6431 - val_acc: 0.7362
#
# Epoch 00064: val_loss improved from 0.65433 to 0.64310, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 65/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.8220 - acc: 0.6490 - val_loss: 0.6502 - val_acc: 0.7231
#
# Epoch 00065: val_loss did not improve from 0.64310
# Epoch 66/300
# 150/150 [==============================] - 198s 1s/step - loss: 0.8006 - acc: 0.6450 - val_loss: 0.6425 - val_acc: 0.7431
#
# Epoch 00066: val_loss improved from 0.64310 to 0.64247, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 67/300
# 150/150 [==============================] - 242s 2s/step - loss: 0.8081 - acc: 0.6494 - val_loss: 0.6357 - val_acc: 0.7450
#
# Epoch 00067: val_loss improved from 0.64247 to 0.63573, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 68/300
# 150/150 [==============================] - 201s 1s/step - loss: 0.8137 - acc: 0.6531 - val_loss: 0.6433 - val_acc: 0.7444
#
# Epoch 00068: val_loss did not improve from 0.63573
# Epoch 69/300
# 150/150 [==============================] - 202s 1s/step - loss: 0.7919 - acc: 0.6615 - val_loss: 0.6384 - val_acc: 0.7137
#
# Epoch 00069: val_loss did not improve from 0.63573
# Epoch 70/300
# 150/150 [==============================] - 211s 1s/step - loss: 0.7930 - acc: 0.6642 - val_loss: 0.6563 - val_acc: 0.7288
#
# Epoch 00070: val_loss did not improve from 0.63573
# Epoch 71/300
# 150/150 [==============================] - 218s 1s/step - loss: 0.7720 - acc: 0.6646 - val_loss: 0.6241 - val_acc: 0.7488
#
# Epoch 00071: val_loss improved from 0.63573 to 0.62410, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 72/300
# 150/150 [==============================] - 204s 1s/step - loss: 0.7828 - acc: 0.6594 - val_loss: 0.6270 - val_acc: 0.7388
#
# Epoch 00072: val_loss did not improve from 0.62410
# Epoch 73/300
# 150/150 [==============================] - 205s 1s/step - loss: 0.7825 - acc: 0.6581 - val_loss: 0.6180 - val_acc: 0.7575
#
# Epoch 00073: val_loss improved from 0.62410 to 0.61801, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 74/300
# 150/150 [==============================] - 200s 1s/step - loss: 0.7947 - acc: 0.6656 - val_loss: 0.6184 - val_acc: 0.7438
#
# Epoch 00074: val_loss did not improve from 0.61801
# Epoch 75/300
# 150/150 [==============================] - 198s 1s/step - loss: 0.7801 - acc: 0.6688 - val_loss: 0.6182 - val_acc: 0.7550
#
# Epoch 00075: val_loss did not improve from 0.61801
# Epoch 76/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.7745 - acc: 0.6746 - val_loss: 0.6276 - val_acc: 0.7425
#
# Epoch 00076: val_loss did not improve from 0.61801
# Epoch 77/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.7620 - acc: 0.6683 - val_loss: 0.6074 - val_acc: 0.7575
#
# Epoch 00077: val_loss improved from 0.61801 to 0.60737, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 78/300
# 150/150 [==============================] - 200s 1s/step - loss: 0.7673 - acc: 0.6706 - val_loss: 0.6182 - val_acc: 0.7619
#
# Epoch 00078: val_loss did not improve from 0.60737
# Epoch 79/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.7651 - acc: 0.6781 - val_loss: 0.6244 - val_acc: 0.7350
#
# Epoch 00079: val_loss did not improve from 0.60737
# Epoch 80/300
# 150/150 [==============================] - 199s 1s/step - loss: 0.7514 - acc: 0.6819 - val_loss: 0.6036 - val_acc: 0.7462
#
# Epoch 00080: val_loss improved from 0.60737 to 0.60362, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 81/300
# 150/150 [==============================] - 201s 1s/step - loss: 0.7600 - acc: 0.6715 - val_loss: 0.6070 - val_acc: 0.7656
#
# Epoch 00081: val_loss did not improve from 0.60362
# Epoch 82/300
# 150/150 [==============================] - 199s 1s/step - loss: 0.7681 - acc: 0.6756 - val_loss: 0.5994 - val_acc: 0.7581
#
# Epoch 00082: val_loss improved from 0.60362 to 0.59942, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 83/300
# 150/150 [==============================] - 201s 1s/step - loss: 0.7569 - acc: 0.6754 - val_loss: 0.6112 - val_acc: 0.7400
#
# Epoch 00083: val_loss did not improve from 0.59942
# Epoch 84/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.7403 - acc: 0.6800 - val_loss: 0.6045 - val_acc: 0.7469
#
# Epoch 00084: val_loss did not improve from 0.59942
# Epoch 85/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.7465 - acc: 0.6763 - val_loss: 0.5943 - val_acc: 0.7581
#
# Epoch 00085: val_loss improved from 0.59942 to 0.59431, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 86/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.7536 - acc: 0.6792 - val_loss: 0.6015 - val_acc: 0.7556
#
# Epoch 00086: val_loss did not improve from 0.59431
# Epoch 87/300
# 150/150 [==============================] - 197s 1s/step - loss: 0.7477 - acc: 0.6783 - val_loss: 0.6141 - val_acc: 0.7412
#
# Epoch 00087: val_loss did not improve from 0.59431
# Epoch 88/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.7393 - acc: 0.6896 - val_loss: 0.5984 - val_acc: 0.7538
#
# Epoch 00088: val_loss did not improve from 0.59431
# Epoch 89/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.7368 - acc: 0.6879 - val_loss: 0.5959 - val_acc: 0.7631
#
# Epoch 00089: val_loss did not improve from 0.59431
# Epoch 90/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.7466 - acc: 0.6787 - val_loss: 0.5968 - val_acc: 0.7588
#
# Epoch 00090: val_loss did not improve from 0.59431
# Epoch 91/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.7400 - acc: 0.6796 - val_loss: 0.5852 - val_acc: 0.7644
#
# Epoch 00091: val_loss improved from 0.59431 to 0.58519, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 92/300
# 150/150 [==============================] - 198s 1s/step - loss: 0.7243 - acc: 0.6956 - val_loss: 0.5925 - val_acc: 0.7688
#
# Epoch 00092: val_loss did not improve from 0.58519
# Epoch 93/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.7219 - acc: 0.6931 - val_loss: 0.5930 - val_acc: 0.7550
#
# Epoch 00093: val_loss did not improve from 0.58519
# Epoch 94/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.7259 - acc: 0.6873 - val_loss: 0.5853 - val_acc: 0.7594
#
# Epoch 00094: val_loss did not improve from 0.58519
# Epoch 95/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.7140 - acc: 0.7023 - val_loss: 0.5800 - val_acc: 0.7688
#
# Epoch 00095: val_loss improved from 0.58519 to 0.58002, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 96/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.7330 - acc: 0.6823 - val_loss: 0.5895 - val_acc: 0.7481
#
# Epoch 00096: val_loss did not improve from 0.58002
# Epoch 97/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.7191 - acc: 0.6927 - val_loss: 0.5691 - val_acc: 0.7756
#
# Epoch 00097: val_loss improved from 0.58002 to 0.56906, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 98/300
# 150/150 [==============================] - 198s 1s/step - loss: 0.7149 - acc: 0.7027 - val_loss: 0.5833 - val_acc: 0.7644
#
# Epoch 00098: val_loss did not improve from 0.56906
# Epoch 99/300
# 150/150 [==============================] - 198s 1s/step - loss: 0.7055 - acc: 0.6994 - val_loss: 0.5909 - val_acc: 0.7662
#
# Epoch 00099: val_loss did not improve from 0.56906
# Epoch 100/300
# 150/150 [==============================] - 198s 1s/step - loss: 0.6972 - acc: 0.7033 - val_loss: 0.5741 - val_acc: 0.7669
#
# Epoch 00100: val_loss did not improve from 0.56906
# Epoch 101/300
# 150/150 [==============================] - 199s 1s/step - loss: 0.7234 - acc: 0.6896 - val_loss: 0.6051 - val_acc: 0.7588
#
# Epoch 00101: val_loss did not improve from 0.56906
# Epoch 102/300
# 150/150 [==============================] - 209s 1s/step - loss: 0.7116 - acc: 0.7025 - val_loss: 0.5704 - val_acc: 0.7612
#
# Epoch 00102: val_loss did not improve from 0.56906
# Epoch 103/300
# 150/150 [==============================] - 219s 1s/step - loss: 0.7008 - acc: 0.6987 - val_loss: 0.5825 - val_acc: 0.7556
#
# Epoch 00103: val_loss did not improve from 0.56906
# Epoch 104/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.7036 - acc: 0.7052 - val_loss: 0.5523 - val_acc: 0.7781
#
# Epoch 00104: val_loss improved from 0.56906 to 0.55226, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 105/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6979 - acc: 0.7065 - val_loss: 0.5583 - val_acc: 0.7781
#
# Epoch 00105: val_loss did not improve from 0.55226
# Epoch 106/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.7049 - acc: 0.6998 - val_loss: 0.5884 - val_acc: 0.7569
#
# Epoch 00106: val_loss did not improve from 0.55226
# Epoch 107/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.6885 - acc: 0.7075 - val_loss: 0.5683 - val_acc: 0.7719
#
# Epoch 00107: val_loss did not improve from 0.55226
# Epoch 108/300
# 150/150 [==============================] - 202s 1s/step - loss: 0.6984 - acc: 0.7077 - val_loss: 0.5546 - val_acc: 0.7719
#
# Epoch 00108: val_loss did not improve from 0.55226
# Epoch 109/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6910 - acc: 0.7148 - val_loss: 0.5514 - val_acc: 0.7731
#
# Epoch 00109: val_loss improved from 0.55226 to 0.55140, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 110/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.6810 - acc: 0.7065 - val_loss: 0.5818 - val_acc: 0.7531
#
# Epoch 00110: val_loss did not improve from 0.55140
# Epoch 111/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.6982 - acc: 0.6969 - val_loss: 0.5500 - val_acc: 0.7706
#
# Epoch 00111: val_loss improved from 0.55140 to 0.54998, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 112/300
# 150/150 [==============================] - 196s 1s/step - loss: 0.6758 - acc: 0.7181 - val_loss: 0.5566 - val_acc: 0.7756
#
# Epoch 00112: val_loss did not improve from 0.54998
# Epoch 113/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6866 - acc: 0.7104 - val_loss: 0.5614 - val_acc: 0.7650
#
# Epoch 00113: val_loss did not improve from 0.54998
# Epoch 114/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6732 - acc: 0.7142 - val_loss: 0.5651 - val_acc: 0.7644
#
# Epoch 00114: val_loss did not improve from 0.54998
# Epoch 115/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6804 - acc: 0.7177 - val_loss: 0.5597 - val_acc: 0.7681
#
# Epoch 00115: val_loss did not improve from 0.54998
# Epoch 116/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6775 - acc: 0.7117 - val_loss: 0.5547 - val_acc: 0.7788
#
# Epoch 00116: val_loss did not improve from 0.54998
# Epoch 117/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6811 - acc: 0.7135 - val_loss: 0.5533 - val_acc: 0.7794
#
# Epoch 00117: val_loss did not improve from 0.54998
# Epoch 118/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6808 - acc: 0.7167 - val_loss: 0.5532 - val_acc: 0.7762
#
# Epoch 00118: val_loss did not improve from 0.54998
# Epoch 119/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6680 - acc: 0.7169 - val_loss: 0.5464 - val_acc: 0.7738
#
# Epoch 00119: val_loss improved from 0.54998 to 0.54637, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 120/300
# 150/150 [==============================] - 198s 1s/step - loss: 0.6637 - acc: 0.7183 - val_loss: 0.5453 - val_acc: 0.7712
#
# Epoch 00120: val_loss improved from 0.54637 to 0.54533, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 121/300
# 150/150 [==============================] - 197s 1s/step - loss: 0.6666 - acc: 0.7233 - val_loss: 0.5634 - val_acc: 0.7625
#
# Epoch 00121: val_loss did not improve from 0.54533
# Epoch 122/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.6703 - acc: 0.7223 - val_loss: 0.5465 - val_acc: 0.7819
#
# Epoch 00122: val_loss did not improve from 0.54533
# Epoch 123/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.6717 - acc: 0.7192 - val_loss: 0.5629 - val_acc: 0.7625
#
# Epoch 00123: val_loss did not improve from 0.54533
# Epoch 124/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6638 - acc: 0.7262 - val_loss: 0.5515 - val_acc: 0.7619
#
# Epoch 00124: val_loss did not improve from 0.54533
# Epoch 125/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.6546 - acc: 0.7229 - val_loss: 0.5544 - val_acc: 0.7625
#
# Epoch 00125: val_loss did not improve from 0.54533
# Epoch 126/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6588 - acc: 0.7183 - val_loss: 0.5476 - val_acc: 0.7731
#
# Epoch 00126: val_loss did not improve from 0.54533
# Epoch 127/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6546 - acc: 0.7240 - val_loss: 0.5428 - val_acc: 0.7788
#
# Epoch 00127: val_loss improved from 0.54533 to 0.54276, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 128/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6535 - acc: 0.7183 - val_loss: 0.5549 - val_acc: 0.7719
#
# Epoch 00128: val_loss did not improve from 0.54276
# Epoch 129/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6653 - acc: 0.7198 - val_loss: 0.5460 - val_acc: 0.7756
#
# Epoch 00129: val_loss did not improve from 0.54276
# Epoch 130/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.6636 - acc: 0.7200 - val_loss: 0.5378 - val_acc: 0.7812
#
# Epoch 00130: val_loss improved from 0.54276 to 0.53778, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 131/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6507 - acc: 0.7250 - val_loss: 0.5449 - val_acc: 0.7681
#
# Epoch 00131: val_loss did not improve from 0.53778
# Epoch 132/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.6481 - acc: 0.7281 - val_loss: 0.5387 - val_acc: 0.7731
#
# Epoch 00132: val_loss did not improve from 0.53778
# Epoch 133/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6422 - acc: 0.7294 - val_loss: 0.5472 - val_acc: 0.7700
#
# Epoch 00133: val_loss did not improve from 0.53778
# Epoch 134/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.6407 - acc: 0.7275 - val_loss: 0.5259 - val_acc: 0.7887
#
# Epoch 00134: val_loss improved from 0.53778 to 0.52585, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 135/300
# 150/150 [==============================] - 195s 1s/step - loss: 0.6346 - acc: 0.7333 - val_loss: 0.5329 - val_acc: 0.7925
#
# Epoch 00135: val_loss did not improve from 0.52585
# Epoch 136/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6467 - acc: 0.7279 - val_loss: 0.5353 - val_acc: 0.7769
#
# Epoch 00136: val_loss did not improve from 0.52585
# Epoch 137/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6294 - acc: 0.7433 - val_loss: 0.5270 - val_acc: 0.7881
#
# Epoch 00137: val_loss did not improve from 0.52585
# Epoch 138/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6335 - acc: 0.7333 - val_loss: 0.5189 - val_acc: 0.7900
#
# Epoch 00138: val_loss improved from 0.52585 to 0.51885, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 139/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.6335 - acc: 0.7371 - val_loss: 0.5334 - val_acc: 0.7788
#
# Epoch 00139: val_loss did not improve from 0.51885
# Epoch 140/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6335 - acc: 0.7300 - val_loss: 0.5374 - val_acc: 0.7800
#
# Epoch 00140: val_loss did not improve from 0.51885
# Epoch 141/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6370 - acc: 0.7360 - val_loss: 0.5224 - val_acc: 0.7881
#
# Epoch 00141: val_loss did not improve from 0.51885
# Epoch 142/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6189 - acc: 0.7452 - val_loss: 0.5217 - val_acc: 0.7844
#
# Epoch 00142: val_loss did not improve from 0.51885
# Epoch 143/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6253 - acc: 0.7404 - val_loss: 0.5305 - val_acc: 0.7844
#
# Epoch 00143: val_loss did not improve from 0.51885
# Epoch 144/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6363 - acc: 0.7300 - val_loss: 0.5358 - val_acc: 0.7644
#
# Epoch 00144: val_loss did not improve from 0.51885
# Epoch 145/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6256 - acc: 0.7390 - val_loss: 0.5391 - val_acc: 0.7725
#
# Epoch 00145: val_loss did not improve from 0.51885
# Epoch 146/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6263 - acc: 0.7373 - val_loss: 0.5124 - val_acc: 0.7987
#
# Epoch 00146: val_loss improved from 0.51885 to 0.51240, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 147/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6247 - acc: 0.7394 - val_loss: 0.5255 - val_acc: 0.7800
#
# Epoch 00147: val_loss did not improve from 0.51240
# Epoch 148/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.6115 - acc: 0.7471 - val_loss: 0.5304 - val_acc: 0.7794
#
# Epoch 00148: val_loss did not improve from 0.51240
# Epoch 149/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.6215 - acc: 0.7473 - val_loss: 0.5311 - val_acc: 0.7700
#
# Epoch 00149: val_loss did not improve from 0.51240
# Epoch 150/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6288 - acc: 0.7377 - val_loss: 0.5110 - val_acc: 0.8025
#
# Epoch 00150: val_loss improved from 0.51240 to 0.51104, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 151/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6178 - acc: 0.7390 - val_loss: 0.5282 - val_acc: 0.7762
#
# Epoch 00151: val_loss did not improve from 0.51104
# Epoch 152/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.6194 - acc: 0.7379 - val_loss: 0.5197 - val_acc: 0.7869
#
# Epoch 00152: val_loss did not improve from 0.51104
# Epoch 153/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6233 - acc: 0.7408 - val_loss: 0.5427 - val_acc: 0.7819
#
# Epoch 00153: val_loss did not improve from 0.51104
# Epoch 154/300
# 150/150 [==============================] - 189s 1s/step - loss: 0.6090 - acc: 0.7481 - val_loss: 0.5126 - val_acc: 0.7913
#
# Epoch 00154: val_loss did not improve from 0.51104
# Epoch 155/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.6068 - acc: 0.7454 - val_loss: 0.5222 - val_acc: 0.7869
#
# Epoch 00155: val_loss did not improve from 0.51104
# Epoch 156/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6087 - acc: 0.7381 - val_loss: 0.5107 - val_acc: 0.8031
#
# Epoch 00156: val_loss improved from 0.51104 to 0.51074, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 157/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6037 - acc: 0.7415 - val_loss: 0.5230 - val_acc: 0.7762
#
# Epoch 00157: val_loss did not improve from 0.51074
# Epoch 158/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.6186 - acc: 0.7369 - val_loss: 0.5176 - val_acc: 0.7863
#
# Epoch 00158: val_loss did not improve from 0.51074
# Epoch 159/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6064 - acc: 0.7465 - val_loss: 0.5130 - val_acc: 0.7881
#
# Epoch 00159: val_loss did not improve from 0.51074
# Epoch 160/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.6278 - acc: 0.7379 - val_loss: 0.5054 - val_acc: 0.7937
#
# Epoch 00160: val_loss improved from 0.51074 to 0.50542, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 161/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.6215 - acc: 0.7419 - val_loss: 0.5354 - val_acc: 0.7837
#
# Epoch 00161: val_loss did not improve from 0.50542
# Epoch 162/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.5981 - acc: 0.7462 - val_loss: 0.4984 - val_acc: 0.8031
#
# Epoch 00162: val_loss improved from 0.50542 to 0.49839, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 163/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6104 - acc: 0.7504 - val_loss: 0.5277 - val_acc: 0.7856
#
# Epoch 00163: val_loss did not improve from 0.49839
# Epoch 164/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.5914 - acc: 0.7565 - val_loss: 0.4995 - val_acc: 0.7963
#
# Epoch 00164: val_loss did not improve from 0.49839
# Epoch 165/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6022 - acc: 0.7498 - val_loss: 0.5090 - val_acc: 0.7894
#
# Epoch 00165: val_loss did not improve from 0.49839
# Epoch 166/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6155 - acc: 0.7417 - val_loss: 0.5041 - val_acc: 0.7925
#
# Epoch 00166: val_loss did not improve from 0.49839
# Epoch 167/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.5875 - acc: 0.7554 - val_loss: 0.5045 - val_acc: 0.7925
#
# Epoch 00167: val_loss did not improve from 0.49839
# Epoch 168/300
# 150/150 [==============================] - 192s 1s/step - loss: 0.5878 - acc: 0.7517 - val_loss: 0.5044 - val_acc: 0.7956
#
# Epoch 00168: val_loss did not improve from 0.49839
# Epoch 169/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.5952 - acc: 0.7508 - val_loss: 0.5243 - val_acc: 0.7806
#
# Epoch 00169: val_loss did not improve from 0.49839
# Epoch 170/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.6070 - acc: 0.7423 - val_loss: 0.5045 - val_acc: 0.7950
#
# Epoch 00170: val_loss did not improve from 0.49839
# Epoch 171/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.5923 - acc: 0.7577 - val_loss: 0.5004 - val_acc: 0.7913
#
# Epoch 00171: val_loss did not improve from 0.49839
# Epoch 172/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.5886 - acc: 0.7544 - val_loss: 0.4974 - val_acc: 0.7975
#
# Epoch 00172: val_loss improved from 0.49839 to 0.49743, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 173/300
# 150/150 [==============================] - 191s 1s/step - loss: 0.6020 - acc: 0.7454 - val_loss: 0.5066 - val_acc: 0.7806
#
# Epoch 00173: val_loss did not improve from 0.49743
# Epoch 174/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.5829 - acc: 0.7500 - val_loss: 0.5012 - val_acc: 0.7937
#
# Epoch 00174: val_loss did not improve from 0.49743
# Epoch 175/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.5959 - acc: 0.7531 - val_loss: 0.4978 - val_acc: 0.8006
#
# Epoch 00175: val_loss did not improve from 0.49743
# Epoch 176/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.5977 - acc: 0.7481 - val_loss: 0.5111 - val_acc: 0.7869
#
# Epoch 00176: val_loss did not improve from 0.49743
# Epoch 177/300
# 150/150 [==============================] - 190s 1s/step - loss: 0.5740 - acc: 0.7608 - val_loss: 0.4911 - val_acc: 0.7981
#
# Epoch 00177: val_loss improved from 0.49743 to 0.49109, saving model to drive/My Drive/master1/medical_image_recognition/models/kvasir_v2/vgg19_21.model
# Epoch 178/300
# 150/150 [==============================] - 194s 1s/step - loss: 0.5920 - acc: 0.7548 - val_loss: 0.4951 - val_acc: 0.8025
#
# Epoch 00178: val_loss did not improve from 0.49109
# Epoch 179/300
# 150/150 [==============================] - 193s 1s/step - loss: 0.5885 - acc: 0.7494 - val_loss: 0.4954 - val_acc: 0.8025
#
# Epoch 00179: val_loss did not improve from 0.49109
# Epoch 180/300
# 150/150 [==============================] - 204s 1s/step - loss: 0.5888 - acc: 0.7542 - val_loss: 0.4955 - val_acc: 0.8006
#
# Epoch 00180: val_loss did not improve from 0.49109
# Epoch 181/300
# 150/150 [==============================] - 227s 2s/step - loss: 0.5685 - acc: 0.7633 - val_loss: 0.5035 - val_acc: 0.7887
#
# Epoch 00181: val_loss did not improve from 0.49109
# Epoch 182/300
# 150/150 [==============================] - 227s 2s/step - loss: 0.5747 - acc: 0.7579 - val_loss: 0.5105 - val_acc: 0.7950
#
# Epoch 00182: val_loss did not improve from 0.49109
# Epoch 183/300
# 150/150 [==============================] - 238s 2s/step - loss: 0.5834 - acc: 0.7562 - val_loss: 0.5002 - val_acc: 0.7925
#
# Epoch 00183: val_loss did not improve from 0.49109
# Epoch 184/300
#  60/150 [===========>..................] - ETA: 1:31 - loss: 0.6021 - acc: 0.7516
