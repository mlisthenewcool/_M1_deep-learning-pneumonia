# %% [markdown]
# # Train a convolutional neural network

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %% [markdown]
# ## Import libraries

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 13 19:35:11 2019

@author: hippolyte
"""

import os
import h5py
import imgaug.augmenters as iaa
import numpy as np
import tensorflow as tf
import imgaug as aug
import datetime
import pickle

from keras.applications import vgg16, vgg19, xception
from keras.models import Model, Sequential, load_model, save_model
from keras.layers import Input, Conv2D, SeparableConv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.engine import InputLayer

from matplotlib import pyplot as plt
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Global variables

# %%
################################################################################
### MODIFIABLE VARIABLES
################################################################################
ROOT_PATH = 'drive/My Drive/medical_image_recognition/'
DATASET_NAME = 'cancer_cells'
IMAGE_EXTENSIONS = ['*.jpg', '*.jpeg']

################################################################################
### DON'T CHANGE THESE VARIABLES
################################################################################
DATASET_PATH = ROOT_PATH + 'datasets/' + DATASET_NAME + '/'
ARRAY_PATH   = ROOT_PATH + 'arrays/'   + DATASET_NAME + '/'
MODEL_PATH   = ROOT_PATH + 'models/'   + DATASET_NAME + '/'
# create the directory to save arrays if it doesn't exist
#! mkdir -pv ARRAY_PATH, MODEL_PATH

# get directories and labels
DIRECTORIES = sorted([d for d in os.listdir(DATASET_PATH)])
LABELS = sorted(os.listdir(DATASET_PATH + DIRECTORIES[0]))
# helpers for labels
NUM_LABELS = len(LABELS)
LABEL_MAPPING = {label: code for code, label in enumerate(LABELS)}
# helper for paths
PATHS = {directory: DATASET_PATH + directory + '/' for directory in DIRECTORIES}

# %%
print(DIRECTORIES)
print(LABELS)
print(LABEL_MAPPING)
# Out:
# ['test', 'train', 'val']
# ['cancer', 'normal']
# {'cancer': 0, 'normal': 1}

# %% [markdown]
# ## Fix seeds to have reproducible results
#
# https://keras.io/getting-started/faq/#how-can-i-obtain-reproducible-results-using-keras-during-development

# %%
# the next instructions are used to make results reproducible
SEED = 1234
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(SEED)
tf.set_random_seed(SEED)
aug.seed(SEED)

# %% [markdown]
# ## Data function

# %%
def label_code_to_str(label_code: int) -> str:
    """
    TODO
    """
    for label, code in LABEL_MAPPING.items():
        if label_code == code:
            return label

    raise ValueError('Couldn\'t find the code {} in labels'.format(label_code))

def get_data_dir(directory: str,
                 array_dir: str,
                 height: int=224,
                 width: int=224,
                 channels: int=3):
    """
    TODO
    """
    shape_str = '({},{},{})'.format(height, width, channels)
    filename = array_dir + directory + shape_str + '.h5'
    print('Getting {} images from {}'.format(shape_str, filename))
    
    # some helper variables
    start = datetime.datetime.now()
    
    with h5py.File(filename, 'r') as file:
        # assuming the file contains same amount of image and labels
        num_images = np.ceil(len(file.keys()) / 2).astype(int)

        # define arrays holding data and labels
        data = np.zeros((num_images, height, width, channels), dtype=np.float32)
        labels = np.zeros((num_images, NUM_LABELS), dtype=np.float32)

        # iterate over all images
        # format is x0 y0 for the first image and so on
        for image_index in range(num_images):
            image = file['x' + str(image_index)]
            label = file['y' + str(image_index)]

            data[image_index] = image
            labels[image_index] = label

    # shapes
    print('Data shape : {}\nLabels shape : {}'.format(data.shape, labels.shape))
    
    end = datetime.datetime.now()
    print('Found {} images in {} seconds.'.format(data.shape[0],
                                                 (end-start).seconds))
    
    return data, labels

# %% [markdown]
# ## Convolutional Neural Network functions

# %% [markdown]
# ### Create the network

# %%
def create_vgg19(include_top=True,
                 input_shape=(224, 224, 3),
                 frozen_layers=None):
    """
    TODO
    """
    # create the VGG model
    vgg19_model = vgg19.VGG19(include_top=include_top,
                              weights='imagenet',
                              input_shape=input_shape)
    # model name
    frozen_layers_str = '_'.join(frozen_layers) if frozen_layers else ''
    
    if include_top is True:
        # create a sequential model with corresponding name
        model_name = 'vgg19_' + frozen_layers_str
        model = Sequential(name=model_name)

        # add input layer at bottom
        model.add(InputLayer(input_shape=input_shape))

        # transform the vgg model into sequential
        # taking care to not add the last layer containing the dense layer
        for layer in vgg19_model.layers[:-1]:
            model.add(layer)

        # add last layer
        model.add(Dense(NUM_LABELS, activation='softmax', name='predictions'))
    
    else:
        # create a sequential model with corresponding name
        model_name = 'vgg19_custom_' + frozen_layers_str
        model = Sequential(name=model_name)
        
        # add input layer at bottom
        model.add(InputLayer(input_shape=input_shape))
        
        # add the vgg model to model
        for layer in vgg19_model.layers:
            model.add(layer)
        
        # add classification block
        model.add(Flatten(name='flatten'))
        model.add(Dense(1024, activation='relu', name='fc1')) #1024
        model.add(Dropout(0.7, name='dropout1'))              #notpresent
        model.add(Dense(512, activation='relu', name='fc2'))  #512
        model.add(Dropout(0.5, name='dropout2'))              #notpresent
        model.add(Dense(NUM_LABELS, activation='softmax', name='predictions'))
    
    ###################
    ### FREEZE PART ###
    ###################
    
    if frozen_layers is None:
        print('Everything is trainable.')
    
    else:
        # freeze the first 5 blocks
        if 'blocks' in frozen_layers:
            for i, layer in enumerate(model.layers):
                if layer.name not in ['fc1', 'fc2']:
                    layer.trainable = False

            print('Froze all blocks before classification one.')

        # freeze fc1
        if 'fc1' in frozen_layers:
            model.get_layer('fc1').trainable = False
            print('Froze fc1.')

        # freeze fc2
        if 'fc2' in frozen_layers:
            model.get_layer('fc2').trainable = False
            print('Froze fc2.')
    
    #####################
    ### COMPILE MODEL ###
    #####################
    
    loss_type = 'binary' if NUM_LABELS == 2 else 'categorical'
    loss_type += '_crossentropy'
    optimizer = Adam(lr=1e-6, decay=1e-5)
    
    model.compile(loss=loss_type,
                  metrics=['accuracy'],
                  optimizer=optimizer)
        
    return model

# %% [markdown]
# ### Training function

# %%
def train_model(model,
                train_data,
                train_labels,
                val_data,
                val_labels,
                epoch=50,
                batch_size=32,
                metric='val_loss',
                save_best_only=True,
                save_model_path=None,
                save_weights_only=True,
                stop_after=5,
                save_history=True,
                save_history_path=None,
                class_weight_mapping=None):
    """
    TODO
    """
    # callbacks
    early_stopping = EarlyStopping(patience=stop_after,
                                   monitor=metric,
                                   restore_best_weights=True)
    
    checkpoint = ModelCheckpoint(save_model_path,
                                 monitor=metric,
                                 verbose=1,
                                 save_best_only=save_best_only,
                                 save_weights_only=save_weights_only)

    # here we are, we'll train the model
    history = model.fit(x=train_data,
                        y=train_labels,
                        batch_size=batch_size,
                        epochs=epoch,
                        verbose=1,
                        callbacks=[early_stopping, checkpoint],
                        validation_split=0.0,
                        validation_data=(val_data, val_labels),
                        shuffle=True,
                        class_weight=class_weight_mapping)

    # save history
    if save_history:
        with open(save_history_path, 'wb') as file:
            pickle.dump(history.history, file)
        print('\n\nSaved history into {}'.format(save_history_path))
    
    return model, history

# %% [markdown]
# ### Plot results of the network

# %%
def plot_model_performance(model,
                           test_data,
                           test_labels,
                           batch_size=16):
    """
    TODO
    """
    print('Performances for {} model.'.format(model.name))
    print('\n\n')
    test_loss, test_score = model.evaluate(test_data,
                                           test_labels,
                                           batch_size=16)
    print('Loss : {}'.format(test_loss))
    print('Score : {}'.format(test_score))
    print('\n\n')

    # predictions and groud truth
    preds = model.predict(test_data, batch_size=16)
    preds = np.argmax(preds, axis=-1)
    ground_truth = np.argmax(test_labels, axis=-1)
    
    # confusion matrix
    cm  = confusion_matrix(ground_truth, preds)
    
    # metrics
    recall = np.diag(cm) / np.sum(cm, axis=1)
    precision = np.diag(cm) / np.sum(cm, axis=0)
    accuracy = np.diag(cm) / np.sum(cm)

    print('Recall : {}'.format(recall))
    print('Precision : {}'.format(precision))
    print('Accuracy : {}'.format(accuracy))
    print('\n\n')

    # plot confusion matrix
    plt.figure()
    plot_confusion_matrix(cm,
                          figsize=(12, 8),
                          hide_ticks=True,
                          cmap=plt.cm.Blues)
    plt.xticks(range(NUM_LABELS), LABELS) #, fontsize=16)
    plt.yticks(range(NUM_LABELS), LABELS) #, fontsize=16)
    plt.show()
    
def plot_model_history(history_path):
    """
    TODO
    """
    print('Loading history from {}'.format(history_path))
    history = pickle.load(open(history_path, 'rb'))

    fig, axes = plt.subplots(1, 2, figsize=(12, 4)) #, constrained_layout=True)

    # accuracy
    axes[0].plot(history['acc'])
    axes[0].plot(history['val_acc'])
    axes[0].set_title('Model Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].legend(['train', 'val'])

    # loss
    axes[1].plot(history['loss'])
    axes[1].plot(history['val_loss'])
    axes[1].set_title('Model Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epochs')
    axes[1].legend(['train', 'val'])
    plt.show()

# %% [markdown]
# ## Let's do it !

# %% [markdown]
# ### Data part

# %%
HEIGHT, WIDTH, CHANNELS = 224, 224, 3

data, labels = dict(), dict()

for directory in DIRECTORIES:
    # get data and labels
    data[directory], labels[directory] = get_data_dir(directory,
                                                      array_dir=ARRAY_PATH,
                                                      height=HEIGHT,
                                                      width=WIDTH,
                                                      channels=CHANNELS)
    
    # get a random index
    ind = np.random.randint(data[directory].shape[0])

    # plot the image with label
    plt.imshow(data[directory][ind])
    img_label = np.argmax(labels[directory][ind])
    img_label_str = label_code_to_str(img_label)
    #plt.title(img_label_str, img_label)
    print('{}({})'.format(img_label, img_label_str))
    plt.show()
# Out:
# Getting (224,224,3) images from drive/My Drive/medical_image_recognition/arrays/cancer_cells/test(224,224,3).h5
# Data shape : (51, 224, 224, 3)
# Labels shape : (51, 2)
# Found 51 images in 0 seconds.
# 1(normal)
# Getting (224,224,3) images from drive/My Drive/medical_image_recognition/arrays/cancer_cells/train(224,224,3).h5
# Data shape : (145, 224, 224, 3)
# Labels shape : (145, 2)
# Found 145 images in 0 seconds.
# 0(cancer)
# Getting (224,224,3) images from drive/My Drive/medical_image_recognition/arrays/cancer_cells/val(224,224,3).h5
# Data shape : (48, 224, 224, 3)
# Labels shape : (48, 2)
# Found 48 images in 0 seconds.
# 0(cancer)

# %% [markdown]
# ### CNN creation

# %%
model = create_vgg19(include_top=True,
                     input_shape=(HEIGHT, WIDTH, CHANNELS),
                     frozen_layers=None)

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Everything is trainable.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 8194
# =================================================================
# Total params: 139,578,434
# Trainable params: 139,578,434
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### CNN training
# #### USE IT WITH CAUTION, IT CAN TAKE TIME

# %%
import pandas as pd
df = pd.DataFrame(labels['train'])
d = dict(df[0].value_counts())
print(d)
#print(d[0] / d[1])

#LABEL_WEIGHTS = class_weight.compute_class_weight('balanced', =d)
#print(LABEL_WEIGHTS)
# Out:
# {1.0: 73, 0.0: 72}

# %%
CLASS_WEIGHT_MAPPING = None #{0: 1, 1: 0.35}

# %%
SAVE_MODEL_PATH = MODEL_PATH + model.name + '_model.hdf5'
SAVE_HISTORY_PATH = MODEL_PATH + model.name + '_history'

model, history = train_model(model,
                             train_data=data['train'],
                             train_labels=labels['train'],
                             val_data=data['val'],
                             val_labels=labels['val'],
                             epoch=200,
                             batch_size=32,
                             metric='val_acc',
                             save_best_only=True,
                             save_model_path=SAVE_MODEL_PATH,
                             save_weights_only=False,
                             stop_after=100,
                             save_history=True,
                             save_history_path=SAVE_HISTORY_PATH,
                             class_weight_mapping=CLASS_WEIGHT_MAPPING)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 145 samples, validate on 48 samples
# Epoch 1/200
# 145/145 [==============================] - 24s 165ms/step - loss: 0.7094 - acc: 0.4966 - val_loss: 0.6906 - val_acc: 0.5625
#
# Epoch 00001: val_acc improved from -inf to 0.56250, saving model to drive/My Drive/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 2/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.6646 - acc: 0.6276 - val_loss: 0.6820 - val_acc: 0.5208
#
# Epoch 00002: val_acc did not improve from 0.56250
# Epoch 3/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.6513 - acc: 0.6207 - val_loss: 0.6673 - val_acc: 0.5625
#
# Epoch 00003: val_acc did not improve from 0.56250
# Epoch 4/200
# 145/145 [==============================] - 3s 24ms/step - loss: 0.6334 - acc: 0.6483 - val_loss: 0.6613 - val_acc: 0.6667
#
# Epoch 00004: val_acc improved from 0.56250 to 0.66667, saving model to drive/My Drive/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 5/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.6168 - acc: 0.6690 - val_loss: 0.6472 - val_acc: 0.6250
#
# Epoch 00005: val_acc did not improve from 0.66667
# Epoch 6/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.6081 - acc: 0.6690 - val_loss: 0.6424 - val_acc: 0.6250
#
# Epoch 00006: val_acc did not improve from 0.66667
# Epoch 7/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.5871 - acc: 0.6966 - val_loss: 0.6304 - val_acc: 0.6667
#
# Epoch 00007: val_acc did not improve from 0.66667
# Epoch 8/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.5713 - acc: 0.7172 - val_loss: 0.6250 - val_acc: 0.6875
#
# Epoch 00008: val_acc improved from 0.66667 to 0.68750, saving model to drive/My Drive/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 9/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.5594 - acc: 0.7310 - val_loss: 0.6159 - val_acc: 0.6458
#
# Epoch 00009: val_acc did not improve from 0.68750
# Epoch 10/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.5484 - acc: 0.7586 - val_loss: 0.6087 - val_acc: 0.6250
#
# Epoch 00010: val_acc did not improve from 0.68750
# Epoch 11/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.5363 - acc: 0.7586 - val_loss: 0.6038 - val_acc: 0.6667
#
# Epoch 00011: val_acc did not improve from 0.68750
# Epoch 12/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.5248 - acc: 0.7517 - val_loss: 0.5975 - val_acc: 0.6458
#
# Epoch 00012: val_acc did not improve from 0.68750
# Epoch 13/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.5157 - acc: 0.7517 - val_loss: 0.5925 - val_acc: 0.6667
#
# Epoch 00013: val_acc did not improve from 0.68750
# Epoch 14/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.5043 - acc: 0.7724 - val_loss: 0.5942 - val_acc: 0.7500
#
# Epoch 00014: val_acc improved from 0.68750 to 0.75000, saving model to drive/My Drive/medical_image_recognition/models/cancer_cells/vgg19__model.hdf5
# Epoch 15/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.4937 - acc: 0.7793 - val_loss: 0.5837 - val_acc: 0.6458
#
# Epoch 00015: val_acc did not improve from 0.75000
# Epoch 16/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.4867 - acc: 0.7793 - val_loss: 0.5806 - val_acc: 0.6458
#
# Epoch 00016: val_acc did not improve from 0.75000
# Epoch 17/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.4759 - acc: 0.8069 - val_loss: 0.5845 - val_acc: 0.7292
#
# Epoch 00017: val_acc did not improve from 0.75000
# Epoch 18/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.4661 - acc: 0.7931 - val_loss: 0.5740 - val_acc: 0.7292
#
# Epoch 00018: val_acc did not improve from 0.75000
# Epoch 19/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.4550 - acc: 0.8138 - val_loss: 0.5718 - val_acc: 0.7292
#
# Epoch 00019: val_acc did not improve from 0.75000
# Epoch 20/200
# 145/145 [==============================] - 4s 24ms/step - loss: 0.4468 - acc: 0.8276 - val_loss: 0.5696 - val_acc: 0.7500
#
# Epoch 00020: val_acc did not improve from 0.75000
# Epoch 21/200
# 145/145 [==============================] - 3s 24ms/step - loss: 0.4383 - acc: 0.8414 - val_loss: 0.5671 - val_acc: 0.6875
#
# Epoch 00021: val_acc did not improve from 0.75000
# Epoch 22/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.4342 - acc: 0.8345 - val_loss: 0.5722 - val_acc: 0.7292
#
# Epoch 00022: val_acc did not improve from 0.75000
# Epoch 23/200
# 145/145 [==============================] - 3s 24ms/step - loss: 0.4217 - acc: 0.8414 - val_loss: 0.5646 - val_acc: 0.6667
#
# Epoch 00023: val_acc did not improve from 0.75000
# Epoch 24/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.4100 - acc: 0.8552 - val_loss: 0.5710 - val_acc: 0.7292
#
# Epoch 00024: val_acc did not improve from 0.75000
# Epoch 25/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.3973 - acc: 0.8345 - val_loss: 0.5702 - val_acc: 0.7292
#
# Epoch 00025: val_acc did not improve from 0.75000
# Epoch 26/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.3887 - acc: 0.8621 - val_loss: 0.5639 - val_acc: 0.6875
#
# Epoch 00026: val_acc did not improve from 0.75000
# Epoch 27/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.3788 - acc: 0.8621 - val_loss: 0.5643 - val_acc: 0.7500
#
# Epoch 00027: val_acc did not improve from 0.75000
# Epoch 28/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.3663 - acc: 0.8690 - val_loss: 0.5658 - val_acc: 0.7500
#
# Epoch 00028: val_acc did not improve from 0.75000
# Epoch 29/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.3565 - acc: 0.8828 - val_loss: 0.5634 - val_acc: 0.7500
#
# Epoch 00029: val_acc did not improve from 0.75000
# Epoch 30/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.3456 - acc: 0.8966 - val_loss: 0.5589 - val_acc: 0.7083
#
# Epoch 00030: val_acc did not improve from 0.75000
# Epoch 31/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.3370 - acc: 0.8828 - val_loss: 0.5585 - val_acc: 0.7083
#
# Epoch 00031: val_acc did not improve from 0.75000
# Epoch 32/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.3255 - acc: 0.9034 - val_loss: 0.5668 - val_acc: 0.7292
#
# Epoch 00032: val_acc did not improve from 0.75000
# Epoch 33/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.3168 - acc: 0.9103 - val_loss: 0.5637 - val_acc: 0.7083
#
# Epoch 00033: val_acc did not improve from 0.75000
# Epoch 34/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.3040 - acc: 0.9103 - val_loss: 0.5718 - val_acc: 0.7500
#
# Epoch 00034: val_acc did not improve from 0.75000
# Epoch 35/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.2941 - acc: 0.9241 - val_loss: 0.5766 - val_acc: 0.7292
#
# Epoch 00035: val_acc did not improve from 0.75000
# Epoch 36/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.2855 - acc: 0.9172 - val_loss: 0.5618 - val_acc: 0.6875
#
# Epoch 00036: val_acc did not improve from 0.75000
# Epoch 37/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.2721 - acc: 0.9310 - val_loss: 0.5743 - val_acc: 0.7083
#
# Epoch 00037: val_acc did not improve from 0.75000
# Epoch 38/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.2630 - acc: 0.9517 - val_loss: 0.5838 - val_acc: 0.7083
#
# Epoch 00038: val_acc did not improve from 0.75000
# Epoch 39/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.2520 - acc: 0.9517 - val_loss: 0.5691 - val_acc: 0.7083
#
# Epoch 00039: val_acc did not improve from 0.75000
# Epoch 40/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.2427 - acc: 0.9448 - val_loss: 0.5629 - val_acc: 0.6458
#
# Epoch 00040: val_acc did not improve from 0.75000
# Epoch 41/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.2319 - acc: 0.9517 - val_loss: 0.5899 - val_acc: 0.7292
#
# Epoch 00041: val_acc did not improve from 0.75000
# Epoch 42/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.2237 - acc: 0.9586 - val_loss: 0.5766 - val_acc: 0.7083
#
# Epoch 00042: val_acc did not improve from 0.75000
# Epoch 43/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.2117 - acc: 0.9586 - val_loss: 0.5797 - val_acc: 0.7083
#
# Epoch 00043: val_acc did not improve from 0.75000
# Epoch 44/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.2042 - acc: 0.9655 - val_loss: 0.5729 - val_acc: 0.6458
#
# Epoch 00044: val_acc did not improve from 0.75000
# Epoch 45/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1922 - acc: 0.9655 - val_loss: 0.5904 - val_acc: 0.7083
#
# Epoch 00045: val_acc did not improve from 0.75000
# Epoch 46/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1835 - acc: 0.9655 - val_loss: 0.5861 - val_acc: 0.7083
#
# Epoch 00046: val_acc did not improve from 0.75000
# Epoch 47/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1745 - acc: 0.9655 - val_loss: 0.5753 - val_acc: 0.6667
#
# Epoch 00047: val_acc did not improve from 0.75000
# Epoch 48/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1653 - acc: 0.9724 - val_loss: 0.5981 - val_acc: 0.6667
#
# Epoch 00048: val_acc did not improve from 0.75000
# Epoch 49/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1571 - acc: 0.9724 - val_loss: 0.6090 - val_acc: 0.7292
#
# Epoch 00049: val_acc did not improve from 0.75000
# Epoch 50/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1521 - acc: 0.9724 - val_loss: 0.5831 - val_acc: 0.6875
#
# Epoch 00050: val_acc did not improve from 0.75000
# Epoch 51/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1412 - acc: 0.9724 - val_loss: 0.6013 - val_acc: 0.6875
#
# Epoch 00051: val_acc did not improve from 0.75000
# Epoch 52/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1330 - acc: 0.9793 - val_loss: 0.6005 - val_acc: 0.6875
#
# Epoch 00052: val_acc did not improve from 0.75000
# Epoch 53/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1270 - acc: 0.9793 - val_loss: 0.6044 - val_acc: 0.6875
#
# Epoch 00053: val_acc did not improve from 0.75000
# Epoch 54/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1196 - acc: 0.9793 - val_loss: 0.5990 - val_acc: 0.6875
#
# Epoch 00054: val_acc did not improve from 0.75000
# Epoch 55/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1171 - acc: 0.9793 - val_loss: 0.6237 - val_acc: 0.7083
#
# Epoch 00055: val_acc did not improve from 0.75000
# Epoch 56/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1045 - acc: 0.9931 - val_loss: 0.5992 - val_acc: 0.7083
#
# Epoch 00056: val_acc did not improve from 0.75000
# Epoch 57/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.1003 - acc: 0.9862 - val_loss: 0.6121 - val_acc: 0.6875
#
# Epoch 00057: val_acc did not improve from 0.75000
# Epoch 58/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0928 - acc: 0.9931 - val_loss: 0.6230 - val_acc: 0.6875
#
# Epoch 00058: val_acc did not improve from 0.75000
# Epoch 59/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0872 - acc: 0.9931 - val_loss: 0.6351 - val_acc: 0.6875
#
# Epoch 00059: val_acc did not improve from 0.75000
# Epoch 60/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0846 - acc: 0.9931 - val_loss: 0.6260 - val_acc: 0.7083
#
# Epoch 00060: val_acc did not improve from 0.75000
# Epoch 61/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0778 - acc: 0.9931 - val_loss: 0.6475 - val_acc: 0.6875
#
# Epoch 00061: val_acc did not improve from 0.75000
# Epoch 62/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0726 - acc: 0.9931 - val_loss: 0.6449 - val_acc: 0.7083
#
# Epoch 00062: val_acc did not improve from 0.75000
# Epoch 63/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0680 - acc: 0.9931 - val_loss: 0.6552 - val_acc: 0.6875
#
# Epoch 00063: val_acc did not improve from 0.75000
# Epoch 64/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0642 - acc: 0.9931 - val_loss: 0.6642 - val_acc: 0.6875
#
# Epoch 00064: val_acc did not improve from 0.75000
# Epoch 65/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0597 - acc: 0.9931 - val_loss: 0.6550 - val_acc: 0.7083
#
# Epoch 00065: val_acc did not improve from 0.75000
# Epoch 66/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0575 - acc: 0.9931 - val_loss: 0.6585 - val_acc: 0.7083
#
# Epoch 00066: val_acc did not improve from 0.75000
# Epoch 67/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0543 - acc: 0.9931 - val_loss: 0.6887 - val_acc: 0.6875
#
# Epoch 00067: val_acc did not improve from 0.75000
# Epoch 68/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0497 - acc: 0.9931 - val_loss: 0.6695 - val_acc: 0.7083
#
# Epoch 00068: val_acc did not improve from 0.75000
# Epoch 69/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0480 - acc: 1.0000 - val_loss: 0.6712 - val_acc: 0.7083
#
# Epoch 00069: val_acc did not improve from 0.75000
# Epoch 70/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0443 - acc: 1.0000 - val_loss: 0.6988 - val_acc: 0.6875
#
# Epoch 00070: val_acc did not improve from 0.75000
# Epoch 71/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0418 - acc: 0.9931 - val_loss: 0.6980 - val_acc: 0.7083
#
# Epoch 00071: val_acc did not improve from 0.75000
# Epoch 72/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0422 - acc: 0.9931 - val_loss: 0.6898 - val_acc: 0.7083
#
# Epoch 00072: val_acc did not improve from 0.75000
# Epoch 73/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0365 - acc: 1.0000 - val_loss: 0.7169 - val_acc: 0.6875
#
# Epoch 00073: val_acc did not improve from 0.75000
# Epoch 74/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0346 - acc: 1.0000 - val_loss: 0.7330 - val_acc: 0.6875
#
# Epoch 00074: val_acc did not improve from 0.75000
# Epoch 75/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0317 - acc: 1.0000 - val_loss: 0.7142 - val_acc: 0.7083
#
# Epoch 00075: val_acc did not improve from 0.75000
# Epoch 76/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0320 - acc: 1.0000 - val_loss: 0.7176 - val_acc: 0.7083
#
# Epoch 00076: val_acc did not improve from 0.75000
# Epoch 77/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0292 - acc: 1.0000 - val_loss: 0.7500 - val_acc: 0.6875
#
# Epoch 00077: val_acc did not improve from 0.75000
# Epoch 78/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0273 - acc: 1.0000 - val_loss: 0.7482 - val_acc: 0.6875
#
# Epoch 00078: val_acc did not improve from 0.75000
# Epoch 79/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0247 - acc: 1.0000 - val_loss: 0.7443 - val_acc: 0.7083
#
# Epoch 00079: val_acc did not improve from 0.75000
# Epoch 80/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0236 - acc: 1.0000 - val_loss: 0.7488 - val_acc: 0.7083
#
# Epoch 00080: val_acc did not improve from 0.75000
# Epoch 81/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0217 - acc: 1.0000 - val_loss: 0.7658 - val_acc: 0.7083
#
# Epoch 00081: val_acc did not improve from 0.75000
# Epoch 82/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0210 - acc: 1.0000 - val_loss: 0.7713 - val_acc: 0.7083
#
# Epoch 00082: val_acc did not improve from 0.75000
# Epoch 83/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0195 - acc: 1.0000 - val_loss: 0.7675 - val_acc: 0.7083
#
# Epoch 00083: val_acc did not improve from 0.75000
# Epoch 84/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0183 - acc: 1.0000 - val_loss: 0.7737 - val_acc: 0.7083
#
# Epoch 00084: val_acc did not improve from 0.75000
# Epoch 85/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0173 - acc: 1.0000 - val_loss: 0.7854 - val_acc: 0.7083
#
# Epoch 00085: val_acc did not improve from 0.75000
# Epoch 86/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0164 - acc: 1.0000 - val_loss: 0.7944 - val_acc: 0.7083
#
# Epoch 00086: val_acc did not improve from 0.75000
# Epoch 87/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0155 - acc: 1.0000 - val_loss: 0.7978 - val_acc: 0.7083
#
# Epoch 00087: val_acc did not improve from 0.75000
# Epoch 88/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0149 - acc: 1.0000 - val_loss: 0.8010 - val_acc: 0.7083
#
# Epoch 00088: val_acc did not improve from 0.75000
# Epoch 89/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0139 - acc: 1.0000 - val_loss: 0.8138 - val_acc: 0.7083
#
# Epoch 00089: val_acc did not improve from 0.75000
# Epoch 90/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0132 - acc: 1.0000 - val_loss: 0.8165 - val_acc: 0.7083
#
# Epoch 00090: val_acc did not improve from 0.75000
# Epoch 91/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0127 - acc: 1.0000 - val_loss: 0.8170 - val_acc: 0.7083
#
# Epoch 00091: val_acc did not improve from 0.75000
# Epoch 92/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0120 - acc: 1.0000 - val_loss: 0.8258 - val_acc: 0.7083
#
# Epoch 00092: val_acc did not improve from 0.75000
# Epoch 93/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0114 - acc: 1.0000 - val_loss: 0.8246 - val_acc: 0.7083
#
# Epoch 00093: val_acc did not improve from 0.75000
# Epoch 94/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0107 - acc: 1.0000 - val_loss: 0.8246 - val_acc: 0.7083
#
# Epoch 00094: val_acc did not improve from 0.75000
# Epoch 95/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0106 - acc: 1.0000 - val_loss: 0.8326 - val_acc: 0.7083
#
# Epoch 00095: val_acc did not improve from 0.75000
# Epoch 96/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0099 - acc: 1.0000 - val_loss: 0.8496 - val_acc: 0.7083
#
# Epoch 00096: val_acc did not improve from 0.75000
# Epoch 97/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0096 - acc: 1.0000 - val_loss: 0.8642 - val_acc: 0.6875
#
# Epoch 00097: val_acc did not improve from 0.75000
# Epoch 98/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0092 - acc: 1.0000 - val_loss: 0.8576 - val_acc: 0.7083
#
# Epoch 00098: val_acc did not improve from 0.75000
# Epoch 99/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0087 - acc: 1.0000 - val_loss: 0.8560 - val_acc: 0.7083
#
# Epoch 00099: val_acc did not improve from 0.75000
# Epoch 100/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0087 - acc: 1.0000 - val_loss: 0.8640 - val_acc: 0.7083
#
# Epoch 00100: val_acc did not improve from 0.75000
# Epoch 101/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0078 - acc: 1.0000 - val_loss: 0.8603 - val_acc: 0.7083
#
# Epoch 00101: val_acc did not improve from 0.75000
# Epoch 102/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0078 - acc: 1.0000 - val_loss: 0.8661 - val_acc: 0.7083
#
# Epoch 00102: val_acc did not improve from 0.75000
# Epoch 103/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0074 - acc: 1.0000 - val_loss: 0.8765 - val_acc: 0.7083
#
# Epoch 00103: val_acc did not improve from 0.75000
# Epoch 104/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0071 - acc: 1.0000 - val_loss: 0.8867 - val_acc: 0.7083
#
# Epoch 00104: val_acc did not improve from 0.75000
# Epoch 105/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0068 - acc: 1.0000 - val_loss: 0.8845 - val_acc: 0.7083
#
# Epoch 00105: val_acc did not improve from 0.75000
# Epoch 106/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0065 - acc: 1.0000 - val_loss: 0.8877 - val_acc: 0.7083
#
# Epoch 00106: val_acc did not improve from 0.75000
# Epoch 107/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0062 - acc: 1.0000 - val_loss: 0.8921 - val_acc: 0.7083
#
# Epoch 00107: val_acc did not improve from 0.75000
# Epoch 108/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0060 - acc: 1.0000 - val_loss: 0.8987 - val_acc: 0.7083
#
# Epoch 00108: val_acc did not improve from 0.75000
# Epoch 109/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0057 - acc: 1.0000 - val_loss: 0.9028 - val_acc: 0.7083
#
# Epoch 00109: val_acc did not improve from 0.75000
# Epoch 110/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0055 - acc: 1.0000 - val_loss: 0.9098 - val_acc: 0.7083
#
# Epoch 00110: val_acc did not improve from 0.75000
# Epoch 111/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 0.9120 - val_acc: 0.7083
#
# Epoch 00111: val_acc did not improve from 0.75000
# Epoch 112/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0051 - acc: 1.0000 - val_loss: 0.9137 - val_acc: 0.7083
#
# Epoch 00112: val_acc did not improve from 0.75000
# Epoch 113/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0049 - acc: 1.0000 - val_loss: 0.9172 - val_acc: 0.7083
#
# Epoch 00113: val_acc did not improve from 0.75000
# Epoch 114/200
# 145/145 [==============================] - 3s 23ms/step - loss: 0.0047 - acc: 1.0000 - val_loss: 0.9188 - val_acc: 0.7083
#
# Epoch 00114: val_acc did not improve from 0.75000
#
#
# Saved history into drive/My Drive/medical_image_recognition/models/cancer_cells/vgg19__history

# %%
plot_model_performance(model,
                       test_data=data['test'],
                       test_labels=labels['test'],
                       batch_size=32)
# Out:
# Performances for vgg19_ model.
#
#
#
# 51/51 [==============================] - 1s 24ms/step
# Loss : 0.5974230474116755
# Score : 0.6666666678353852
#
#
#
# Recall : [0.57692308 0.76      ]
# Precision : [0.71428571 0.63333333]
# Accuracy : [0.29411765 0.37254902]

# %%
plot_model_history(SAVE_HISTORY_PATH)
# Out:
# Loading history from drive/My Drive/medical_image_recognition/models/cancer_cells/vgg19__history
