# %%
from google.colab import drive, files
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
from keras import applications
from keras import optimizers
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense, InputLayer
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator

# %%
DATA_AUGMENTATION = False
DATASET_NAME = 'miniMIT_Etus'

ROOT_PATH    = 'drive/My Drive/medical_image_recognition/'
DATASET_PATH = ROOT_PATH + 'datasets/' + DATASET_NAME + '/'
MODEL_PATH   = ROOT_PATH + 'models/'   + DATASET_NAME + '/'

# %%
def get_generator(directory,
                  image_shape=(224, 224),
                  batch_size=32,
                  should_augment=False,
                  data_gen_args=None):
    
    # only rescale
    if should_augment is False:
        image_gen = ImageDataGenerator(rescale=(1./255))
    
    # use dictionary to define augmentations
    else:
        if data_gen_args is None:
            data_gen_args = dict(rescale=1./255,
                                 shear_range=0.2,
                                 zoom_range=0.2,
                                 horizontal_flip=True)
        
        image_gen = ImageDataGenerator(**data_gen_args)
    
    return image_gen.flow_from_directory(directory,
                                         target_size=image_shape,
                                         batch_size=batch_size)

# %%
HEIGHT, WIDTH, CHANNELS = 224, 224, 3
BATCH_SIZE = 32

train_generator = get_generator(DATASET_PATH + 'train',
                                batch_size=BATCH_SIZE,
                                should_augment=DATA_AUGMENTATION)

test_generator = get_generator(DATASET_PATH + 'test',
                               batch_size=BATCH_SIZE)
# Out:
# Found 120 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %%
def build_model(image_shape,
                classes,
                num_layers_to_freeze=21,
                base_model_weights_path=None,
                top_model_weights_path=None):
    
    model_name = f'vgg19_{num_layers_to_freeze}'
    
    # build the base model
    if base_model_weights_path is None:
        base_model_weights_path = 'imagenet'
    base_model = applications.vgg19.VGG19(input_shape=image_shape,
                                          weights=base_model_weights_path,
                                          include_top=False)
    print('Load VGG19 as base model')
    
    # load base model weights
    #base_model.load_weights(base_model_weights_path)
    
    # adding classification block on top of base model
    x = Flatten(input_shape=image_shape, name='flatten')(base_model.output)
    x = Dense(512, activation='relu', name='fc1')(x)
    x = Dropout(0.7, name='dropout1')(x)
    x = Dense(256, activation='relu', name='fc2')(x)
    x = Dropout(0.5, name='dropout2')(x)
    x = Dense(classes, activation='softmax', name='predictions')(x)
    
    # combine both
    model = Model(inputs=base_model.input, outputs=x, name=model_name)
    
    # load top model weights
    #model.load_weights(top_model_weights_path)
    
    # freeze layers
    for i, layer in enumerate(model.layers):
        if i <= num_layers_to_freeze:
            layer.trainable = False
        else:
            layer.trainable = True
            print(f'Layer {i} {layer.name} is trainable')

    # compile model
    loss_type = 'binary_' if classes == 2 else 'categorical_'
    loss_type += 'crossentropy'
    model.compile(loss=loss_type,
                  optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
                  metrics=['accuracy'])
    
    print('Model compiled')
    return model

# %%
BASE_MODEL_WEIGHTS_PATH = ROOT_PATH + 'models/vgg19_weights_no_top.h5'
NUM_CLASSES = len(train_generator.class_indices)

model = build_model(image_shape=(HEIGHT, WIDTH, CHANNELS), classes=NUM_CLASSES)
model.summary()
# Out:
# Load VGG19 as base model
# Layer 22 flatten is trainable
# Layer 23 fc1 is trainable
# Layer 24 dropout1 is trainable
# Layer 25 fc2 is trainable
# Layer 26 dropout2 is trainable
# Layer 27 predictions is trainable
# Model compiled
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 512)               12845568
# _________________________________________________________________
# dropout1 (Dropout)           (None, 512)               0
# _________________________________________________________________
# fc2 (Dense)                  (None, 256)               131328
# _________________________________________________________________
# dropout2 (Dropout)           (None, 256)               0
# _________________________________________________________________
# predictions (Dense)          (None, 3)                 771
# =================================================================
# Total params: 33,002,051
# Trainable params: 12,977,667
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# fine-tune the model
EPOCHS = 300
TRAIN_LEN = train_generator.n
TEST_LEN = test_generator.n
CLASS_WEIGHT = None #{0: 1.0, 1: 0.4}

SAVE_HISTORY_PATH = MODEL_PATH + model.name + '.history'
SAVE_MODEL_PATH   = MODEL_PATH + model.name + '.model'

import pickle

def train_model(save_model_path,
                save_history_path,
                save_history=True):
    
    early_stopping = EarlyStopping(patience=20,
                                   monitor='val_loss',
                                   restore_best_weights=True)

    checkpoint = ModelCheckpoint(save_model_path,
                                 monitor='val_loss',
                                 verbose=1,
                                 save_best_only=True,
                                 save_weights_only=False)

    #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
    #                              patience=5, min_lr=0.001)

    history = model.fit_generator(
        train_generator,
        steps_per_epoch=TRAIN_LEN //  BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=test_generator,
        validation_steps=TEST_LEN // BATCH_SIZE,
        verbose=1,
        callbacks=[early_stopping, checkpoint],
        class_weight=CLASS_WEIGHT)

    # save history
    if save_history:
        with open(save_history_path, 'wb') as file:
            pickle.dump(history.history, file)
        print(f'\n\nSaved history into {save_history_path}')

# %%
train_model(save_model_path=SAVE_MODEL_PATH,
            save_history_path=SAVE_HISTORY_PATH)
# Out:
# Epoch 1/300
# 3/3 [==============================] - 66s 22s/step - loss: 2.2572 - acc: 0.2708 - val_loss: 1.2515 - val_acc: 0.3438
#
# Epoch 00001: val_loss improved from inf to 1.25148, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 2/300
# 3/3 [==============================] - 15s 5s/step - loss: 1.7054 - acc: 0.2846 - val_loss: 1.1087 - val_acc: 0.3409
#
# Epoch 00002: val_loss improved from 1.25148 to 1.10865, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 3/300
# 3/3 [==============================] - 1s 380ms/step - loss: 1.3887 - acc: 0.3830 - val_loss: 1.1454 - val_acc: 0.3636
#
# Epoch 00003: val_loss did not improve from 1.10865
# Epoch 4/300
# 3/3 [==============================] - 1s 372ms/step - loss: 1.5727 - acc: 0.3750 - val_loss: 1.2176 - val_acc: 0.3523
#
# Epoch 00004: val_loss did not improve from 1.10865
# Epoch 5/300
# 3/3 [==============================] - 1s 390ms/step - loss: 1.3306 - acc: 0.3229 - val_loss: 1.1250 - val_acc: 0.4062
#
# Epoch 00005: val_loss did not improve from 1.10865
# Epoch 6/300
# 3/3 [==============================] - 1s 375ms/step - loss: 1.4307 - acc: 0.3059 - val_loss: 1.1167 - val_acc: 0.4205
#
# Epoch 00006: val_loss did not improve from 1.10865
# Epoch 7/300
# 3/3 [==============================] - 1s 373ms/step - loss: 1.2821 - acc: 0.3722 - val_loss: 1.0438 - val_acc: 0.4432
#
# Epoch 00007: val_loss improved from 1.10865 to 1.04384, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 8/300
# 3/3 [==============================] - 1s 378ms/step - loss: 1.2884 - acc: 0.3670 - val_loss: 1.0541 - val_acc: 0.3409
#
# Epoch 00008: val_loss did not improve from 1.04384
# Epoch 9/300
# 3/3 [==============================] - 1s 395ms/step - loss: 1.3180 - acc: 0.3646 - val_loss: 1.0359 - val_acc: 0.4479
#
# Epoch 00009: val_loss improved from 1.04384 to 1.03588, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 10/300
# 3/3 [==============================] - 1s 376ms/step - loss: 1.3757 - acc: 0.3059 - val_loss: 1.0406 - val_acc: 0.4659
#
# Epoch 00010: val_loss did not improve from 1.03588
# Epoch 11/300
# 3/3 [==============================] - 1s 379ms/step - loss: 1.2309 - acc: 0.4015 - val_loss: 1.0457 - val_acc: 0.5114
#
# Epoch 00011: val_loss did not improve from 1.03588
# Epoch 12/300
# 3/3 [==============================] - 1s 384ms/step - loss: 1.1526 - acc: 0.4148 - val_loss: 1.0445 - val_acc: 0.5455
#
# Epoch 00012: val_loss did not improve from 1.03588
# Epoch 13/300
# 3/3 [==============================] - 1s 408ms/step - loss: 1.1607 - acc: 0.4167 - val_loss: 1.0432 - val_acc: 0.5000
#
# Epoch 00013: val_loss did not improve from 1.03588
# Epoch 14/300
# 3/3 [==============================] - 1s 387ms/step - loss: 1.1349 - acc: 0.4096 - val_loss: 1.0458 - val_acc: 0.5000
#
# Epoch 00014: val_loss did not improve from 1.03588
# Epoch 15/300
# 3/3 [==============================] - 1s 389ms/step - loss: 1.1835 - acc: 0.4311 - val_loss: 1.0618 - val_acc: 0.4886
#
# Epoch 00015: val_loss did not improve from 1.03588
# Epoch 16/300
# 3/3 [==============================] - 1s 389ms/step - loss: 1.0371 - acc: 0.4974 - val_loss: 1.0509 - val_acc: 0.4545
#
# Epoch 00016: val_loss did not improve from 1.03588
# Epoch 17/300
# 3/3 [==============================] - 1s 410ms/step - loss: 1.1237 - acc: 0.3854 - val_loss: 1.0365 - val_acc: 0.4896
#
# Epoch 00017: val_loss did not improve from 1.03588
# Epoch 18/300
# 3/3 [==============================] - 1s 392ms/step - loss: 1.0745 - acc: 0.4841 - val_loss: 1.0487 - val_acc: 0.4773
#
# Epoch 00018: val_loss did not improve from 1.03588
# Epoch 19/300
# 3/3 [==============================] - 1s 394ms/step - loss: 0.9925 - acc: 0.4628 - val_loss: 1.0433 - val_acc: 0.5227
#
# Epoch 00019: val_loss did not improve from 1.03588
# Epoch 20/300
# 3/3 [==============================] - 1s 393ms/step - loss: 1.0644 - acc: 0.5078 - val_loss: 1.0278 - val_acc: 0.5114
#
# Epoch 00020: val_loss improved from 1.03588 to 1.02784, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 21/300
# 3/3 [==============================] - 1s 426ms/step - loss: 1.1045 - acc: 0.3750 - val_loss: 1.0309 - val_acc: 0.5417
#
# Epoch 00021: val_loss did not improve from 1.02784
# Epoch 22/300
# 3/3 [==============================] - 1s 397ms/step - loss: 1.0804 - acc: 0.4070 - val_loss: 1.0175 - val_acc: 0.5682
#
# Epoch 00022: val_loss improved from 1.02784 to 1.01750, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 23/300
# 3/3 [==============================] - 1s 399ms/step - loss: 0.9870 - acc: 0.5265 - val_loss: 1.0199 - val_acc: 0.5227
#
# Epoch 00023: val_loss did not improve from 1.01750
# Epoch 24/300
# 3/3 [==============================] - 1s 397ms/step - loss: 1.0480 - acc: 0.4496 - val_loss: 0.9988 - val_acc: 0.6136
#
# Epoch 00024: val_loss improved from 1.01750 to 0.99882, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 25/300
# 3/3 [==============================] - 1s 420ms/step - loss: 0.9846 - acc: 0.5312 - val_loss: 1.0010 - val_acc: 0.5208
#
# Epoch 00025: val_loss did not improve from 0.99882
# Epoch 26/300
# 3/3 [==============================] - 1s 391ms/step - loss: 1.0074 - acc: 0.4602 - val_loss: 1.0055 - val_acc: 0.4773
#
# Epoch 00026: val_loss did not improve from 0.99882
# Epoch 27/300
# 3/3 [==============================] - 1s 393ms/step - loss: 0.9889 - acc: 0.4813 - val_loss: 0.9834 - val_acc: 0.5568
#
# Epoch 00027: val_loss improved from 0.99882 to 0.98344, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 28/300
# 3/3 [==============================] - 1s 398ms/step - loss: 0.9760 - acc: 0.5135 - val_loss: 0.9897 - val_acc: 0.5455
#
# Epoch 00028: val_loss did not improve from 0.98344
# Epoch 29/300
# 3/3 [==============================] - 1s 408ms/step - loss: 0.9725 - acc: 0.5000 - val_loss: 0.9835 - val_acc: 0.5938
#
# Epoch 00029: val_loss did not improve from 0.98344
# Epoch 30/300
# 3/3 [==============================] - 1s 389ms/step - loss: 0.9742 - acc: 0.5611 - val_loss: 0.9785 - val_acc: 0.6136
#
# Epoch 00030: val_loss improved from 0.98344 to 0.97849, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 31/300
# 3/3 [==============================] - 1s 387ms/step - loss: 1.0665 - acc: 0.4335 - val_loss: 0.9969 - val_acc: 0.5568
#
# Epoch 00031: val_loss did not improve from 0.97849
# Epoch 32/300
# 3/3 [==============================] - 1s 384ms/step - loss: 0.9679 - acc: 0.4893 - val_loss: 0.9921 - val_acc: 0.5568
#
# Epoch 00032: val_loss did not improve from 0.97849
# Epoch 33/300
# 3/3 [==============================] - 1s 402ms/step - loss: 0.9828 - acc: 0.5000 - val_loss: 0.9763 - val_acc: 0.6042
#
# Epoch 00033: val_loss improved from 0.97849 to 0.97633, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 34/300
# 3/3 [==============================] - 1s 384ms/step - loss: 1.0037 - acc: 0.4496 - val_loss: 0.9713 - val_acc: 0.6364
#
# Epoch 00034: val_loss improved from 0.97633 to 0.97133, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 35/300
# 3/3 [==============================] - 1s 380ms/step - loss: 0.9489 - acc: 0.5478 - val_loss: 1.0165 - val_acc: 0.4659
#
# Epoch 00035: val_loss did not improve from 0.97133
# Epoch 36/300
# 3/3 [==============================] - 1s 379ms/step - loss: 1.0125 - acc: 0.4709 - val_loss: 0.9903 - val_acc: 0.6136
#
# Epoch 00036: val_loss did not improve from 0.97133
# Epoch 37/300
# 3/3 [==============================] - 1s 396ms/step - loss: 1.0230 - acc: 0.5000 - val_loss: 0.9884 - val_acc: 0.5625
#
# Epoch 00037: val_loss did not improve from 0.97133
# Epoch 38/300
# 3/3 [==============================] - 1s 376ms/step - loss: 0.9957 - acc: 0.5000 - val_loss: 0.9930 - val_acc: 0.5227
#
# Epoch 00038: val_loss did not improve from 0.97133
# Epoch 39/300
# 3/3 [==============================] - 1s 375ms/step - loss: 0.9563 - acc: 0.5107 - val_loss: 0.9524 - val_acc: 0.6136
#
# Epoch 00039: val_loss improved from 0.97133 to 0.95238, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 40/300
# 3/3 [==============================] - 1s 377ms/step - loss: 0.9200 - acc: 0.5720 - val_loss: 0.9889 - val_acc: 0.5568
#
# Epoch 00040: val_loss did not improve from 0.95238
# Epoch 41/300
# 3/3 [==============================] - 1s 388ms/step - loss: 0.9190 - acc: 0.5417 - val_loss: 0.9667 - val_acc: 0.6146
#
# Epoch 00041: val_loss did not improve from 0.95238
# Epoch 42/300
# 3/3 [==============================] - 1s 377ms/step - loss: 0.9667 - acc: 0.5346 - val_loss: 0.9760 - val_acc: 0.5568
#
# Epoch 00042: val_loss did not improve from 0.95238
# Epoch 43/300
# 3/3 [==============================] - 1s 370ms/step - loss: 0.9057 - acc: 0.6304 - val_loss: 0.9377 - val_acc: 0.6023
#
# Epoch 00043: val_loss improved from 0.95238 to 0.93769, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 44/300
# 3/3 [==============================] - 1s 377ms/step - loss: 0.8062 - acc: 0.6330 - val_loss: 0.9544 - val_acc: 0.5568
#
# Epoch 00044: val_loss did not improve from 0.93769
# Epoch 45/300
# 3/3 [==============================] - 1s 392ms/step - loss: 0.8682 - acc: 0.6042 - val_loss: 0.9371 - val_acc: 0.6146
#
# Epoch 00045: val_loss improved from 0.93769 to 0.93714, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 46/300
# 3/3 [==============================] - 1s 372ms/step - loss: 0.9465 - acc: 0.5294 - val_loss: 0.9665 - val_acc: 0.5568
#
# Epoch 00046: val_loss did not improve from 0.93714
# Epoch 47/300
# 3/3 [==============================] - 1s 370ms/step - loss: 0.9724 - acc: 0.5478 - val_loss: 0.9321 - val_acc: 0.6023
#
# Epoch 00047: val_loss improved from 0.93714 to 0.93208, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 48/300
# 3/3 [==============================] - 1s 372ms/step - loss: 0.8645 - acc: 0.6011 - val_loss: 0.9421 - val_acc: 0.5682
#
# Epoch 00048: val_loss did not improve from 0.93208
# Epoch 49/300
# 3/3 [==============================] - 1s 387ms/step - loss: 0.8972 - acc: 0.5938 - val_loss: 0.9269 - val_acc: 0.5833
#
# Epoch 00049: val_loss improved from 0.93208 to 0.92692, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 50/300
# 3/3 [==============================] - 1s 368ms/step - loss: 0.9262 - acc: 0.5720 - val_loss: 0.9163 - val_acc: 0.6136
#
# Epoch 00050: val_loss improved from 0.92692 to 0.91628, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 51/300
# 3/3 [==============================] - 1s 363ms/step - loss: 0.8594 - acc: 0.6383 - val_loss: 0.9038 - val_acc: 0.6818
#
# Epoch 00051: val_loss improved from 0.91628 to 0.90383, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 52/300
# 3/3 [==============================] - 1s 368ms/step - loss: 0.8878 - acc: 0.6115 - val_loss: 0.9321 - val_acc: 0.6591
#
# Epoch 00052: val_loss did not improve from 0.90383
# Epoch 53/300
# 3/3 [==============================] - 1s 382ms/step - loss: 0.8320 - acc: 0.5938 - val_loss: 0.9087 - val_acc: 0.6146
#
# Epoch 00053: val_loss did not improve from 0.90383
# Epoch 54/300
# 3/3 [==============================] - 1s 389ms/step - loss: 0.8829 - acc: 0.5798 - val_loss: 0.8957 - val_acc: 0.6364
#
# Epoch 00054: val_loss improved from 0.90383 to 0.89568, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 55/300
# 3/3 [==============================] - 1s 401ms/step - loss: 0.8923 - acc: 0.6143 - val_loss: 0.9152 - val_acc: 0.6023
#
# Epoch 00055: val_loss did not improve from 0.89568
# Epoch 56/300
# 3/3 [==============================] - 1s 460ms/step - loss: 0.8741 - acc: 0.6302 - val_loss: 0.8899 - val_acc: 0.6250
#
# Epoch 00056: val_loss improved from 0.89568 to 0.88992, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 57/300
# 3/3 [==============================] - 1s 479ms/step - loss: 0.8531 - acc: 0.6146 - val_loss: 0.9091 - val_acc: 0.6250
#
# Epoch 00057: val_loss did not improve from 0.88992
# Epoch 58/300
# 3/3 [==============================] - 1s 455ms/step - loss: 0.8748 - acc: 0.6011 - val_loss: 0.9022 - val_acc: 0.6136
#
# Epoch 00058: val_loss did not improve from 0.88992
# Epoch 59/300
# 3/3 [==============================] - 1s 450ms/step - loss: 0.8652 - acc: 0.6304 - val_loss: 0.9024 - val_acc: 0.6364
#
# Epoch 00059: val_loss did not improve from 0.88992
# Epoch 60/300
# 3/3 [==============================] - 1s 404ms/step - loss: 0.8393 - acc: 0.5985 - val_loss: 0.9105 - val_acc: 0.6477
#
# Epoch 00060: val_loss did not improve from 0.88992
# Epoch 61/300
# 3/3 [==============================] - 1s 454ms/step - loss: 0.8005 - acc: 0.6146 - val_loss: 0.9034 - val_acc: 0.6354
#
# Epoch 00061: val_loss did not improve from 0.88992
# Epoch 62/300
# 3/3 [==============================] - 1s 389ms/step - loss: 0.7556 - acc: 0.7448 - val_loss: 0.8980 - val_acc: 0.6364
#
# Epoch 00062: val_loss did not improve from 0.88992
# Epoch 63/300
# 3/3 [==============================] - 1s 374ms/step - loss: 0.8833 - acc: 0.5026 - val_loss: 0.8980 - val_acc: 0.6364
#
# Epoch 00063: val_loss did not improve from 0.88992
# Epoch 64/300
# 3/3 [==============================] - 1s 424ms/step - loss: 0.9015 - acc: 0.5743 - val_loss: 0.9010 - val_acc: 0.6250
#
# Epoch 00064: val_loss did not improve from 0.88992
# Epoch 65/300
# 3/3 [==============================] - 1s 448ms/step - loss: 0.8000 - acc: 0.7083 - val_loss: 0.8929 - val_acc: 0.6146
#
# Epoch 00065: val_loss did not improve from 0.88992
# Epoch 66/300
# 3/3 [==============================] - 1s 377ms/step - loss: 0.8424 - acc: 0.6754 - val_loss: 0.9080 - val_acc: 0.5795
#
# Epoch 00066: val_loss did not improve from 0.88992
# Epoch 67/300
# 3/3 [==============================] - 1s 384ms/step - loss: 0.7353 - acc: 0.6754 - val_loss: 0.8796 - val_acc: 0.6250
#
# Epoch 00067: val_loss improved from 0.88992 to 0.87963, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 68/300
# 3/3 [==============================] - 1s 376ms/step - loss: 0.7958 - acc: 0.6887 - val_loss: 0.8969 - val_acc: 0.6250
#
# Epoch 00068: val_loss did not improve from 0.87963
# Epoch 69/300
# 3/3 [==============================] - 1s 450ms/step - loss: 0.7534 - acc: 0.6771 - val_loss: 0.8974 - val_acc: 0.6042
#
# Epoch 00069: val_loss did not improve from 0.87963
# Epoch 70/300
# 3/3 [==============================] - 1s 374ms/step - loss: 0.7924 - acc: 0.6650 - val_loss: 0.8887 - val_acc: 0.6136
#
# Epoch 00070: val_loss did not improve from 0.87963
# Epoch 71/300
# 3/3 [==============================] - 1s 375ms/step - loss: 0.8113 - acc: 0.6754 - val_loss: 0.8656 - val_acc: 0.6023
#
# Epoch 00071: val_loss improved from 0.87963 to 0.86563, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 72/300
# 3/3 [==============================] - 1s 379ms/step - loss: 0.8167 - acc: 0.5852 - val_loss: 0.8754 - val_acc: 0.6023
#
# Epoch 00072: val_loss did not improve from 0.86563
# Epoch 73/300
# 3/3 [==============================] - 1s 400ms/step - loss: 0.7330 - acc: 0.6771 - val_loss: 0.8773 - val_acc: 0.6042
#
# Epoch 00073: val_loss did not improve from 0.86563
# Epoch 74/300
# 3/3 [==============================] - 1s 386ms/step - loss: 0.7144 - acc: 0.7232 - val_loss: 0.8836 - val_acc: 0.6136
#
# Epoch 00074: val_loss did not improve from 0.86563
# Epoch 75/300
# 3/3 [==============================] - 1s 388ms/step - loss: 0.7477 - acc: 0.7287 - val_loss: 0.8508 - val_acc: 0.6023
#
# Epoch 00075: val_loss improved from 0.86563 to 0.85080, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 76/300
# 3/3 [==============================] - 1s 382ms/step - loss: 0.7403 - acc: 0.6835 - val_loss: 0.8834 - val_acc: 0.5909
#
# Epoch 00076: val_loss did not improve from 0.85080
# Epoch 77/300
# 3/3 [==============================] - 1s 407ms/step - loss: 0.6817 - acc: 0.6979 - val_loss: 0.8551 - val_acc: 0.6458
#
# Epoch 00077: val_loss did not improve from 0.85080
# Epoch 78/300
# 3/3 [==============================] - 1s 386ms/step - loss: 0.7449 - acc: 0.6489 - val_loss: 0.8362 - val_acc: 0.6591
#
# Epoch 00078: val_loss improved from 0.85080 to 0.83619, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 79/300
# 3/3 [==============================] - 1s 380ms/step - loss: 0.6882 - acc: 0.7554 - val_loss: 0.8800 - val_acc: 0.6136
#
# Epoch 00079: val_loss did not improve from 0.83619
# Epoch 80/300
# 3/3 [==============================] - 1s 383ms/step - loss: 0.7817 - acc: 0.6463 - val_loss: 0.8416 - val_acc: 0.6591
#
# Epoch 00080: val_loss did not improve from 0.83619
# Epoch 81/300
# 3/3 [==============================] - 1s 428ms/step - loss: 0.6691 - acc: 0.7604 - val_loss: 0.8582 - val_acc: 0.6354
#
# Epoch 00081: val_loss did not improve from 0.83619
# Epoch 82/300
# 3/3 [==============================] - 1s 432ms/step - loss: 0.6939 - acc: 0.7287 - val_loss: 0.8032 - val_acc: 0.6932
#
# Epoch 00082: val_loss improved from 0.83619 to 0.80320, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 83/300
# 3/3 [==============================] - 1s 411ms/step - loss: 0.7197 - acc: 0.7152 - val_loss: 0.8801 - val_acc: 0.6591
#
# Epoch 00083: val_loss did not improve from 0.80320
# Epoch 84/300
# 3/3 [==============================] - 1s 464ms/step - loss: 0.7730 - acc: 0.6622 - val_loss: 0.8577 - val_acc: 0.6023
#
# Epoch 00084: val_loss did not improve from 0.80320
# Epoch 85/300
# 3/3 [==============================] - 1s 433ms/step - loss: 0.6636 - acc: 0.7188 - val_loss: 0.8672 - val_acc: 0.6042
#
# Epoch 00085: val_loss did not improve from 0.80320
# Epoch 86/300
# 3/3 [==============================] - 1s 391ms/step - loss: 0.7662 - acc: 0.6304 - val_loss: 0.8280 - val_acc: 0.6250
#
# Epoch 00086: val_loss did not improve from 0.80320
# Epoch 87/300
# 3/3 [==============================] - 1s 407ms/step - loss: 0.7297 - acc: 0.6518 - val_loss: 0.8479 - val_acc: 0.6591
#
# Epoch 00087: val_loss did not improve from 0.80320
# Epoch 88/300
# 3/3 [==============================] - 1s 388ms/step - loss: 0.6946 - acc: 0.7048 - val_loss: 0.8058 - val_acc: 0.6477
#
# Epoch 00088: val_loss did not improve from 0.80320
# Epoch 89/300
# 3/3 [==============================] - 1s 406ms/step - loss: 0.7232 - acc: 0.7083 - val_loss: 0.8348 - val_acc: 0.6042
#
# Epoch 00089: val_loss did not improve from 0.80320
# Epoch 90/300
# 3/3 [==============================] - 1s 384ms/step - loss: 0.7641 - acc: 0.6518 - val_loss: 0.8280 - val_acc: 0.6364
#
# Epoch 00090: val_loss did not improve from 0.80320
# Epoch 91/300
# 3/3 [==============================] - 1s 385ms/step - loss: 0.7472 - acc: 0.6674 - val_loss: 0.8086 - val_acc: 0.6250
#
# Epoch 00091: val_loss did not improve from 0.80320
# Epoch 92/300
# 3/3 [==============================] - 1s 385ms/step - loss: 0.7808 - acc: 0.6409 - val_loss: 0.8596 - val_acc: 0.6136
#
# Epoch 00092: val_loss did not improve from 0.80320
# Epoch 93/300
# 3/3 [==============================] - 1s 434ms/step - loss: 0.6663 - acc: 0.7500 - val_loss: 0.8267 - val_acc: 0.6354
#
# Epoch 00093: val_loss did not improve from 0.80320
# Epoch 94/300
# 3/3 [==============================] - 1s 385ms/step - loss: 0.7006 - acc: 0.7526 - val_loss: 0.8318 - val_acc: 0.6477
#
# Epoch 00094: val_loss did not improve from 0.80320
# Epoch 95/300
# 3/3 [==============================] - 1s 390ms/step - loss: 0.6716 - acc: 0.7235 - val_loss: 0.8368 - val_acc: 0.5455
#
# Epoch 00095: val_loss did not improve from 0.80320
# Epoch 96/300
# 3/3 [==============================] - 1s 399ms/step - loss: 0.6286 - acc: 0.7500 - val_loss: 0.8114 - val_acc: 0.6364
#
# Epoch 00096: val_loss did not improve from 0.80320
# Epoch 97/300
# 3/3 [==============================] - 1s 426ms/step - loss: 0.6680 - acc: 0.7604 - val_loss: 0.8105 - val_acc: 0.6250
#
# Epoch 00097: val_loss did not improve from 0.80320
# Epoch 98/300
# 3/3 [==============================] - 1s 418ms/step - loss: 0.6975 - acc: 0.7022 - val_loss: 0.8558 - val_acc: 0.6136
#
# Epoch 00098: val_loss did not improve from 0.80320
# Epoch 99/300
# 3/3 [==============================] - 1s 383ms/step - loss: 0.6891 - acc: 0.7074 - val_loss: 0.7778 - val_acc: 0.6477
#
# Epoch 00099: val_loss improved from 0.80320 to 0.77780, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 100/300
# 3/3 [==============================] - 1s 384ms/step - loss: 0.6491 - acc: 0.7552 - val_loss: 0.8400 - val_acc: 0.5568
#
# Epoch 00100: val_loss did not improve from 0.77780
# Epoch 101/300
# 3/3 [==============================] - 1s 397ms/step - loss: 0.5748 - acc: 0.7917 - val_loss: 0.8161 - val_acc: 0.5938
#
# Epoch 00101: val_loss did not improve from 0.77780
# Epoch 102/300
# 3/3 [==============================] - 1s 398ms/step - loss: 0.5807 - acc: 0.7659 - val_loss: 0.8062 - val_acc: 0.6591
#
# Epoch 00102: val_loss did not improve from 0.77780
# Epoch 103/300
# 3/3 [==============================] - 1s 381ms/step - loss: 0.6633 - acc: 0.7768 - val_loss: 0.7870 - val_acc: 0.5909
#
# Epoch 00103: val_loss did not improve from 0.77780
# Epoch 104/300
# 3/3 [==============================] - 1s 379ms/step - loss: 0.6257 - acc: 0.7498 - val_loss: 0.8479 - val_acc: 0.5682
#
# Epoch 00104: val_loss did not improve from 0.77780
# Epoch 105/300
# 3/3 [==============================] - 1s 408ms/step - loss: 0.5771 - acc: 0.8021 - val_loss: 0.8125 - val_acc: 0.5938
#
# Epoch 00105: val_loss did not improve from 0.77780
# Epoch 106/300
# 3/3 [==============================] - 1s 377ms/step - loss: 0.6334 - acc: 0.7526 - val_loss: 0.7808 - val_acc: 0.6136
#
# Epoch 00106: val_loss did not improve from 0.77780
# Epoch 107/300
# 3/3 [==============================] - 1s 407ms/step - loss: 0.6388 - acc: 0.7285 - val_loss: 0.8702 - val_acc: 0.5227
#
# Epoch 00107: val_loss did not improve from 0.77780
# Epoch 108/300
# 3/3 [==============================] - 1s 381ms/step - loss: 0.7071 - acc: 0.6915 - val_loss: 0.7634 - val_acc: 0.6705
#
# Epoch 00108: val_loss improved from 0.77780 to 0.76340, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 109/300
# 3/3 [==============================] - 1s 391ms/step - loss: 0.6917 - acc: 0.7188 - val_loss: 0.8103 - val_acc: 0.6250
#
# Epoch 00109: val_loss did not improve from 0.76340
# Epoch 110/300
# 3/3 [==============================] - 1s 406ms/step - loss: 0.5727 - acc: 0.8165 - val_loss: 0.8165 - val_acc: 0.6023
#
# Epoch 00110: val_loss did not improve from 0.76340
# Epoch 111/300
# 3/3 [==============================] - 1s 383ms/step - loss: 0.6534 - acc: 0.7102 - val_loss: 0.7748 - val_acc: 0.6023
#
# Epoch 00111: val_loss did not improve from 0.76340
# Epoch 112/300
# 3/3 [==============================] - 1s 391ms/step - loss: 0.6604 - acc: 0.6970 - val_loss: 0.7839 - val_acc: 0.6023
#
# Epoch 00112: val_loss did not improve from 0.76340
# Epoch 113/300
# 3/3 [==============================] - 2s 509ms/step - loss: 0.6612 - acc: 0.6875 - val_loss: 0.7770 - val_acc: 0.6250
#
# Epoch 00113: val_loss did not improve from 0.76340
# Epoch 114/300
# 3/3 [==============================] - 1s 408ms/step - loss: 0.5644 - acc: 0.8324 - val_loss: 0.7878 - val_acc: 0.6023
#
# Epoch 00114: val_loss did not improve from 0.76340
# Epoch 115/300
# 3/3 [==============================] - 1s 471ms/step - loss: 0.7096 - acc: 0.7232 - val_loss: 0.8016 - val_acc: 0.6023
#
# Epoch 00115: val_loss did not improve from 0.76340
# Epoch 116/300
# 3/3 [==============================] - 1s 429ms/step - loss: 0.6020 - acc: 0.8191 - val_loss: 0.7751 - val_acc: 0.6364
#
# Epoch 00116: val_loss did not improve from 0.76340
# Epoch 117/300
# 3/3 [==============================] - 2s 579ms/step - loss: 0.5774 - acc: 0.7708 - val_loss: 0.7752 - val_acc: 0.6250
#
# Epoch 00117: val_loss did not improve from 0.76340
# Epoch 118/300
# 3/3 [==============================] - 1s 418ms/step - loss: 0.6727 - acc: 0.7209 - val_loss: 0.7506 - val_acc: 0.6250
#
# Epoch 00118: val_loss improved from 0.76340 to 0.75057, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 119/300
# 3/3 [==============================] - 1s 404ms/step - loss: 0.5852 - acc: 0.7209 - val_loss: 0.8061 - val_acc: 0.6023
#
# Epoch 00119: val_loss did not improve from 0.75057
# Epoch 120/300
# 3/3 [==============================] - 1s 378ms/step - loss: 0.6313 - acc: 0.7765 - val_loss: 0.7657 - val_acc: 0.6477
#
# Epoch 00120: val_loss did not improve from 0.75057
# Epoch 121/300
# 3/3 [==============================] - 1s 439ms/step - loss: 0.6155 - acc: 0.7812 - val_loss: 0.7600 - val_acc: 0.6562
#
# Epoch 00121: val_loss did not improve from 0.75057
# Epoch 122/300
# 3/3 [==============================] - 1s 382ms/step - loss: 0.5902 - acc: 0.7552 - val_loss: 0.8065 - val_acc: 0.5455
#
# Epoch 00122: val_loss did not improve from 0.75057
# Epoch 123/300
# 3/3 [==============================] - 1s 371ms/step - loss: 0.4906 - acc: 0.8298 - val_loss: 0.7389 - val_acc: 0.6932
#
# Epoch 00123: val_loss improved from 0.75057 to 0.73894, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 124/300
# 3/3 [==============================] - 1s 370ms/step - loss: 0.6691 - acc: 0.7180 - val_loss: 0.7812 - val_acc: 0.6364
#
# Epoch 00124: val_loss did not improve from 0.73894
# Epoch 125/300
# 3/3 [==============================] - 1s 418ms/step - loss: 0.5382 - acc: 0.8021 - val_loss: 0.7742 - val_acc: 0.6458
#
# Epoch 00125: val_loss did not improve from 0.73894
# Epoch 126/300
# 3/3 [==============================] - 1s 403ms/step - loss: 0.5611 - acc: 0.8137 - val_loss: 0.7645 - val_acc: 0.6591
#
# Epoch 00126: val_loss did not improve from 0.73894
# Epoch 127/300
# 3/3 [==============================] - 1s 378ms/step - loss: 0.5577 - acc: 0.8324 - val_loss: 0.8159 - val_acc: 0.5682
#
# Epoch 00127: val_loss did not improve from 0.73894
# Epoch 128/300
# 3/3 [==============================] - 1s 378ms/step - loss: 0.5768 - acc: 0.8537 - val_loss: 0.7358 - val_acc: 0.6477
#
# Epoch 00128: val_loss improved from 0.73894 to 0.73576, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 129/300
# 3/3 [==============================] - 1s 400ms/step - loss: 0.6162 - acc: 0.7604 - val_loss: 0.7452 - val_acc: 0.6771
#
# Epoch 00129: val_loss did not improve from 0.73576
# Epoch 130/300
# 3/3 [==============================] - 1s 377ms/step - loss: 0.5897 - acc: 0.7713 - val_loss: 0.8580 - val_acc: 0.5341
#
# Epoch 00130: val_loss did not improve from 0.73576
# Epoch 131/300
# 3/3 [==============================] - 1s 396ms/step - loss: 0.4858 - acc: 0.8563 - val_loss: 0.7090 - val_acc: 0.7045
#
# Epoch 00131: val_loss improved from 0.73576 to 0.70897, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 132/300
# 3/3 [==============================] - 1s 384ms/step - loss: 0.5368 - acc: 0.8511 - val_loss: 0.7570 - val_acc: 0.6250
#
# Epoch 00132: val_loss did not improve from 0.70897
# Epoch 133/300
# 3/3 [==============================] - 1s 395ms/step - loss: 0.6031 - acc: 0.8125 - val_loss: 0.7592 - val_acc: 0.6146
#
# Epoch 00133: val_loss did not improve from 0.70897
# Epoch 134/300
# 3/3 [==============================] - 1s 378ms/step - loss: 0.6023 - acc: 0.7846 - val_loss: 0.7614 - val_acc: 0.6477
#
# Epoch 00134: val_loss did not improve from 0.70897
# Epoch 135/300
# 3/3 [==============================] - 1s 374ms/step - loss: 0.5721 - acc: 0.7820 - val_loss: 0.7481 - val_acc: 0.6136
#
# Epoch 00135: val_loss did not improve from 0.70897
# Epoch 136/300
# 3/3 [==============================] - 1s 383ms/step - loss: 0.5245 - acc: 0.8246 - val_loss: 0.7650 - val_acc: 0.5909
#
# Epoch 00136: val_loss did not improve from 0.70897
# Epoch 137/300
# 3/3 [==============================] - 1s 430ms/step - loss: 0.5575 - acc: 0.7917 - val_loss: 0.7708 - val_acc: 0.6042
#
# Epoch 00137: val_loss did not improve from 0.70897
# Epoch 138/300
# 3/3 [==============================] - 1s 393ms/step - loss: 0.4930 - acc: 0.7924 - val_loss: 0.7152 - val_acc: 0.6250
#
# Epoch 00138: val_loss did not improve from 0.70897
# Epoch 139/300
# 3/3 [==============================] - 1s 446ms/step - loss: 0.5648 - acc: 0.7474 - val_loss: 0.7486 - val_acc: 0.5909
#
# Epoch 00139: val_loss did not improve from 0.70897
# Epoch 140/300
# 3/3 [==============================] - 1s 390ms/step - loss: 0.5981 - acc: 0.7128 - val_loss: 0.7556 - val_acc: 0.6364
#
# Epoch 00140: val_loss did not improve from 0.70897
# Epoch 141/300
# 3/3 [==============================] - 1s 398ms/step - loss: 0.5476 - acc: 0.7917 - val_loss: 0.7655 - val_acc: 0.6146
#
# Epoch 00141: val_loss did not improve from 0.70897
# Epoch 142/300
# 3/3 [==============================] - 1s 380ms/step - loss: 0.5345 - acc: 0.8007 - val_loss: 0.6976 - val_acc: 0.6591
#
# Epoch 00142: val_loss improved from 0.70897 to 0.69763, saving model to drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.model
# Epoch 143/300
# 3/3 [==============================] - 1s 384ms/step - loss: 0.5353 - acc: 0.8059 - val_loss: 0.7639 - val_acc: 0.6364
#
# Epoch 00143: val_loss did not improve from 0.69763
# Epoch 144/300
# 3/3 [==============================] - 1s 375ms/step - loss: 0.4282 - acc: 0.8883 - val_loss: 0.7447 - val_acc: 0.6477
#
# Epoch 00144: val_loss did not improve from 0.69763
# Epoch 145/300
# 3/3 [==============================] - 1s 395ms/step - loss: 0.5621 - acc: 0.8333 - val_loss: 0.7530 - val_acc: 0.6354
#
# Epoch 00145: val_loss did not improve from 0.69763
# Epoch 146/300
# 3/3 [==============================] - 1s 379ms/step - loss: 0.5940 - acc: 0.8139 - val_loss: 0.7306 - val_acc: 0.6364
#
# Epoch 00146: val_loss did not improve from 0.69763
# Epoch 147/300
# 3/3 [==============================] - 1s 379ms/step - loss: 0.5418 - acc: 0.7794 - val_loss: 0.7253 - val_acc: 0.6477
#
# Epoch 00147: val_loss did not improve from 0.69763
# Epoch 148/300
# 3/3 [==============================] - 1s 379ms/step - loss: 0.5585 - acc: 0.7659 - val_loss: 0.7311 - val_acc: 0.6364
#
# Epoch 00148: val_loss did not improve from 0.69763
# Epoch 149/300
# 3/3 [==============================] - 1s 432ms/step - loss: 0.5187 - acc: 0.8542 - val_loss: 0.7347 - val_acc: 0.6562
#
# Epoch 00149: val_loss did not improve from 0.69763
# Epoch 150/300
# 3/3 [==============================] - 1s 389ms/step - loss: 0.5200 - acc: 0.8272 - val_loss: 0.7512 - val_acc: 0.6250
#
# Epoch 00150: val_loss did not improve from 0.69763
# Epoch 151/300
# 3/3 [==============================] - 1s 487ms/step - loss: 0.4610 - acc: 0.8563 - val_loss: 0.7530 - val_acc: 0.6477
#
# Epoch 00151: val_loss did not improve from 0.69763
# Epoch 152/300
# 3/3 [==============================] - 2s 523ms/step - loss: 0.4673 - acc: 0.8430 - val_loss: 0.7529 - val_acc: 0.6136
#
# Epoch 00152: val_loss did not improve from 0.69763
# Epoch 153/300
# 3/3 [==============================] - 2s 507ms/step - loss: 0.4985 - acc: 0.8333 - val_loss: 0.7303 - val_acc: 0.6458
#
# Epoch 00153: val_loss did not improve from 0.69763
# Epoch 154/300
# 3/3 [==============================] - 1s 467ms/step - loss: 0.4256 - acc: 0.8830 - val_loss: 0.7733 - val_acc: 0.6705
#
# Epoch 00154: val_loss did not improve from 0.69763
# Epoch 155/300
# 3/3 [==============================] - 1s 386ms/step - loss: 0.4484 - acc: 0.7978 - val_loss: 0.7349 - val_acc: 0.5682
#
# Epoch 00155: val_loss did not improve from 0.69763
# Epoch 156/300
# 3/3 [==============================] - 1s 384ms/step - loss: 0.3873 - acc: 0.8565 - val_loss: 0.7077 - val_acc: 0.6591
#
# Epoch 00156: val_loss did not improve from 0.69763
# Epoch 157/300
# 3/3 [==============================] - 1s 405ms/step - loss: 0.4498 - acc: 0.8646 - val_loss: 0.7242 - val_acc: 0.6250
#
# Epoch 00157: val_loss did not improve from 0.69763
# Epoch 158/300
# 3/3 [==============================] - 1s 399ms/step - loss: 0.4479 - acc: 0.8617 - val_loss: 0.7670 - val_acc: 0.5341
#
# Epoch 00158: val_loss did not improve from 0.69763
# Epoch 159/300
# 3/3 [==============================] - 1s 385ms/step - loss: 0.5302 - acc: 0.7607 - val_loss: 0.7140 - val_acc: 0.6591
#
# Epoch 00159: val_loss did not improve from 0.69763
# Epoch 160/300
# 3/3 [==============================] - 1s 380ms/step - loss: 0.4551 - acc: 0.8750 - val_loss: 0.7062 - val_acc: 0.6136
#
# Epoch 00160: val_loss did not improve from 0.69763
# Epoch 161/300
# 3/3 [==============================] - 1s 403ms/step - loss: 0.5099 - acc: 0.8333 - val_loss: 0.7012 - val_acc: 0.6667
#
# Epoch 00161: val_loss did not improve from 0.69763
# Epoch 162/300
# 3/3 [==============================] - 1s 384ms/step - loss: 0.4158 - acc: 0.8963 - val_loss: 0.7375 - val_acc: 0.6136
#
# Epoch 00162: val_loss did not improve from 0.69763
#
#
# Saved history into drive/My Drive/medical_image_recognition/models/miniMIT_Etus/vgg19_21.history

# %%
def test_model(model, model_name, test_data, test_labels, batch_size=16):
    """
    TODO
    """
    test_loss, test_score = model.evaluate(test_data,
                                           test_labels,
                                           batch_size=16)

    print('Results for {} model.'.format(model_name))

    print('Loss : {}'.format(test_loss))
    print('Score : {}'.format(test_score))

    # predictions
    preds = model.predict(test_data, batch_size=16)
    preds = np.argmax(preds, axis=-1)

    # original labels
    orig_test_labels = np.argmax(test_labels, axis=-1)

    # shapes
    print(orig_test_labels.shape)
    print(preds.shape)

    ### confusion matrix
    cm  = confusion_matrix(orig_test_labels, preds)
    plt.figure()
    plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues)
    plt.xticks(range(2), ['Normal', 'Pneumonia'], fontsize=16)
    plt.yticks(range(2), ['Normal', 'Pneumonia'], fontsize=16)
    plt.show()

    ### metrics
    tn, fp, fn, tp = cm.ravel()
    precision = tp / (tp + fp)
    recall =    tp / (tp + fn)
    accuracy = (tp + tn) / (tn + fp + fn + tp)

    print("Recall of the model is {:.5f}".format(recall))
    print("Precision of the model is {:.5f}".format(precision))
    print("Accuracy of the model is {:.5f}".format(accuracy))

    return

# %%
from keras.models import load_model
# choose the weights to load into model
BEST_MODEL = MODEL_PATH + 'vgg19_21.model'
model = load_model(BEST_MODEL)

# let's test our model !
test_model(model, 'VGG19', data['test'], labels['test'], batch_size=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6bfb01166fae> in <module>()
#       5
#       6 # let's test our model !
# ----> 7 test_model(model, 'VGG19', data['test'], labels['test'], batch_size=16)
#
# NameError: name 'data' is not defined
